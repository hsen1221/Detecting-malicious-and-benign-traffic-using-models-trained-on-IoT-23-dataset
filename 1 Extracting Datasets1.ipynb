# %% [markdown]
# # EXTRACTING DATASET FROM 1CONN.LOG.LABELED

# %%
import numpy as np
import pandas as pd
# Assign the filename
fpath = r"1.labeled"
# Import file using np.recfromcsv: d
narray = np.recfromcsv(fpath, encoding=None)
# record array is a type of NumPy array where fields can have different data types
# Print out first n records of d 
print(narray)
# string to search in file
word = 'fields'
with open(fpath, 'r') as fp:
    # read all lines in a list
    lines = fp.readlines()
    for line in lines:
        # check if string present on a current line
        if line.find(word) != -1:
            print(word, 'string exists in file')
            print('Line Number:', lines.index(line))
            print('Line:', line)
            linefields = line
x = linefields.split("\t")
df = pd.concat([pd.Series(l.astype(str).split('\t')) for l in narray], axis=1).T
print(df)
# Out:
# [('1525879831.015811\tCUmrqr4svHuSXJy5z7\t192.168.100.103\t51524\t65.127.233.163\t23\ttcp\t-\t2.999051\t0\t0\tS0\t-\t-\t0\tS\t3\t180\t0\t0\t(empty)   Malicious   PartOfAHorizontalPortScan',)
#  ('1525879831.025055\tCH98aB3s1kJeq6SFOc\t192.168.100.103\t56305\t63.150.16.171\t23\ttcp\t-\t-\t-\t-\tS0\t-\t-\t0\tS\t1\t60\t0\t0\t(empty)   Malicious   PartOfAHorizontalPortScan',)
#  ('1525879831.045045\tC3GBTkINvXNjVGtN5\t192.168.100.103\t41101\t111.40.23.49\t23\ttcp\t-\t-\t-\t-\tS0\t-\t-\t0\tS\t1\t60\t0\t0\t(empty)   Malicious   PartOfAHorizontalPortScan',)
#  ...
#  ('1526282625.031224\tCVHrUzIUN0mW5lQsl\t192.168.100.103\t43763\t249.99.119.9\t26169\tudp\t-\t-\t-\t-\tS0\t-\t-\t0\tD\t1\t40\t0\t0\t(empty)   Benign   -',)
#  ('1526282676.031019\tCkGlnL2pxzlusrFlLj\t192.168.100.103\t43763\t205.103.167.192\t18241\tudp\t-\t-\t-\t-\tS0\t-\t-\t0\tD\t1\t40\t0\t0\t(empty)   Benign   -',)
# ...

# %% [markdown]
# # show the rows of the dataframe

# %%
display(df)
# Out:
#                         0                   1                2      3   \
# 0        1525879831.015811  CUmrqr4svHuSXJy5z7  192.168.100.103  51524
# 1        1525879831.025055  CH98aB3s1kJeq6SFOc  192.168.100.103  56305
# 2        1525879831.045045   C3GBTkINvXNjVGtN5  192.168.100.103  41101
# 3        1525879832.016240   CDe43c1PtgynajGI6  192.168.100.103  60905
# 4        1525879832.024985  CJaDcG3MZzvf1YVYI4  192.168.100.103  44301
# ...                    ...                 ...              ...    ...
# 1008743  1526282655.031040   CUyBg1WA04SBmf3ah  192.168.100.103  43763
# 1008744  1526282682.031081  CvaIoX2b9VynuYieBf  192.168.100.103  43763
# 1008745  1526282625.031224   CVHrUzIUN0mW5lQsl  192.168.100.103  43763
# 1008746  1526282676.031019  CkGlnL2pxzlusrFlLj  192.168.100.103  43763
# 1008747  1526282660.030686  CoOjVZ1zw3pWf7a9n5  192.168.100.103  43763
#
#                       4      5    6  7         8  9   ...  11 12 13 14 15 16  \
# ...

# %% [markdown]
# # class values

# %%
df[20].values[1:100]
# Out:
# array(['(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Benign   -',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
# ...

# %% [markdown]
# # the columns (features)

# %%
x
# Out:
# ['#fields',
#  'ts',
#  'uid',
#  'id.orig_h',
#  'id.orig_p',
#  'id.resp_h',
#  'id.resp_p',
#  'proto',
#  'service',
#  'duration',
#  'orig_bytes',
#  'resp_bytes',
#  'conn_state',
#  'local_orig',
#  'local_resp',
#  'missed_bytes',
#  'history',
#  'orig_pkts',
#  'orig_ip_bytes',
#  'resp_pkts',
#  'resp_ip_bytes',
#  'tunnel_parents   label   detailed-label\n']

# %% [markdown]
# ## remove #fields because it just indicates the features

# %%
x.pop(0)
# Out:
# '#fields'

# %%
x[20]='tunnel_parents   label   detailed-label'

# %%
x
# Out:
# ['ts',
#  'uid',
#  'id.orig_h',
#  'id.orig_p',
#  'id.resp_h',
#  'id.resp_p',
#  'proto',
#  'service',
#  'duration',
#  'orig_bytes',
#  'resp_bytes',
#  'conn_state',
#  'local_orig',
#  'local_resp',
#  'missed_bytes',
#  'history',
#  'orig_pkts',
#  'orig_ip_bytes',
#  'resp_pkts',
#  'resp_ip_bytes',
#  'tunnel_parents   label   detailed-label']

# %% [markdown]
# ## assigns columns names to the dataset

# %%
df.columns=x

# %%
df
# Out:
#                         ts                 uid        id.orig_h id.orig_p  \
# 0        1525879831.015811  CUmrqr4svHuSXJy5z7  192.168.100.103     51524
# 1        1525879831.025055  CH98aB3s1kJeq6SFOc  192.168.100.103     56305
# 2        1525879831.045045   C3GBTkINvXNjVGtN5  192.168.100.103     41101
# 3        1525879832.016240   CDe43c1PtgynajGI6  192.168.100.103     60905
# 4        1525879832.024985  CJaDcG3MZzvf1YVYI4  192.168.100.103     44301
# ...                    ...                 ...              ...       ...
# 1008743  1526282655.031040   CUyBg1WA04SBmf3ah  192.168.100.103     43763
# 1008744  1526282682.031081  CvaIoX2b9VynuYieBf  192.168.100.103     43763
# 1008745  1526282625.031224   CVHrUzIUN0mW5lQsl  192.168.100.103     43763
# 1008746  1526282676.031019  CkGlnL2pxzlusrFlLj  192.168.100.103     43763
# 1008747  1526282660.030686  CoOjVZ1zw3pWf7a9n5  192.168.100.103     43763
#
#                id.resp_h id.resp_p proto service  duration orig_bytes  ...  \
# ...

# %% [markdown]
# # saving the dataframt to a .csv format

# %%
df.to_csv("1.csv")
