# %%
import numpy as np
import pandas as pd
# Assign the filename
fpath = r"21.labeled"
# Import file using np.recfromcsv: d
narray = np.recfromcsv(fpath, encoding=None)

# Print out first n records of d 
print(narray)
# string to search in file
word = 'fields'
with open(fpath, 'r') as fp:
    # read all lines in a list
    lines = fp.readlines()
    for line in lines:
        # check if string present on a current line
        if line.find(word) != -1:
            print(word, 'string exists in file')
            print('Line Number:', lines.index(line))
            print('Line:', line)
            linefields = line
x = linefields.split("\t")
df = pd.concat([pd.Series(l.astype(str).split('\t')) for l in narray], axis=1).T
print(df)
# Out:
# [('1538572953.710599\tCu3Tieri43IPsyBO3\t192.168.100.113\t42789\t192.168.100.1\t53\tudp\tdns\t-\t-\t-\tS0\t-\t-\t0\tD\t1\t67\t0\t0\t-   Benign   -',)
#  ('1538572958.715995\tCbetl72NeXczaqQ8Lj\t192.168.100.113\t60546\t192.168.100.1\t53\tudp\tdns\t0.001494\t90\t90\tSF\t-\t-\t0\tDd\t2\t146\t2\t146\t-   Benign   -',)
#  ('1538572982.666603\tCUmQWl2ZA2hrbNtohe\t192.168.100.113\t37320\t192.168.100.1\t53\tudp\tdns\t5.005135\t78\t0\tS0\t-\t-\t0\tD\t2\t134\t0\t0\t-   Benign   -',)
#  ...
#  ('1538658859.666630\tCM1PRb4VLsTg6NwpP3\t192.168.100.113\t123\t77.78.107.252\t123\tudp\t-\t0.001990\t48\t48\tSF\t-\t-\t0\tDd\t1\t76\t1\t76\t-   Benign   -',)
#  ('1538659000.666495\tCHg7OGn02ubAXL4Fc\t192.168.100.113\t123\t81.2.254.32\t123\tudp\t-\t-\t-\t-\tS0\t-\t-\t0\tD\t1\t76\t0\t0\t-   Benign   -',)
#  ('1538636961.823246\tCJ0N5q2qFD0t1nCl3j\t192.168.100.113\t41186\t66.85.157.90\t443\ttcp\t-\t22388.393741\t12183\t12183\tS1\t-\t-\t2472\tShADaCGdt\t4485\t189231\t4702\t200386\t-   Malicious   C&C-Torii',)]
# fields string exists in file
# Line Number: 6
# Line: #fields	ts	uid	id.orig_h	id.orig_p	id.resp_h	id.resp_p	proto	service	duration	orig_bytes	resp_bytes	conn_state	local_orig	local_resp	missed_bytes	history	orig_pkts	orig_ip_bytes	resp_pkts	resp_ip_bytes	tunnel_parents   label   detailed-label
#
#                      0                   1                2      3   \
# 0     1538572953.710599   Cu3Tieri43IPsyBO3  192.168.100.113  42789
# 1     1538572958.715995  Cbetl72NeXczaqQ8Lj  192.168.100.113  60546
# 2     1538572982.666603  CUmQWl2ZA2hrbNtohe  192.168.100.113  37320
# 3     1538572992.677145   C9oEZWtG35wx1Mqq5  192.168.100.113  51338
# 4     1538572992.679377  CbhqpU1oZZyrP7PE6i  192.168.100.113  60088
# ...                 ...                 ...              ...    ...
# 3281  1538658604.666507  Co564F1QNSoTE46mad  192.168.100.113    123
# 3282  1538658812.666424  CsqptL3U3IopamCGQ6  192.168.100.113    123
# 3283  1538658859.666630  CM1PRb4VLsTg6NwpP3  192.168.100.113    123
# 3284  1538659000.666495   CHg7OGn02ubAXL4Fc  192.168.100.113    123
# 3285  1538636961.823246  CJ0N5q2qFD0t1nCl3j  192.168.100.113  41186
#
#                   4    5    6    7             8      9   ...  11 12 13    14  \
# 0      192.168.100.1   53  udp  dns             -      -  ...  S0  -  -     0
# 1      192.168.100.1   53  udp  dns      0.001494     90  ...  SF  -  -     0
# 2      192.168.100.1   53  udp  dns      5.005135     78  ...  S0  -  -     0
# 3      192.168.100.1   53  udp  dns      0.001483     90  ...  SF  -  -     0
# 4      192.168.100.1   53  udp  dns      5.038625    117  ...  SF  -  -     0
# ...              ...  ...  ...  ...           ...    ...  ...  .. .. ..   ...
# 3281  213.199.225.40  123  udp    -             -      -  ...  S0  -  -     0
# 3282   89.221.212.46  123  udp    -             -      -  ...  S0  -  -     0
# 3283   77.78.107.252  123  udp    -      0.001990     48  ...  SF  -  -     0
# 3284     81.2.254.32  123  udp    -             -      -  ...  S0  -  -     0
# 3285    66.85.157.90  443  tcp    -  22388.393741  12183  ...  S1  -  -  2472
#
#              15    16      17    18      19                         20
# 0             D     1      67     0       0             -   Benign   -
# 1            Dd     2     146     2     146             -   Benign   -
# 2             D     2     134     0       0             -   Benign   -
# 3            Dd     2     146     2     146             -   Benign   -
# 4            Dd     3     201     2     198             -   Benign   -
# ...         ...   ...     ...   ...     ...                        ...
# 3281          D     1      76     0       0             -   Benign   -
# 3282          D     1      76     0       0             -   Benign   -
# 3283         Dd     1      76     1      76             -   Benign   -
# 3284          D     1      76     0       0             -   Benign   -
# 3285  ShADaCGdt  4485  189231  4702  200386  -   Malicious   C&C-Torii
#
# [3286 rows x 21 columns]

# %%
display(df)
# Out:
#                      0                   1                2      3   \
# 0     1538572953.710599   Cu3Tieri43IPsyBO3  192.168.100.113  42789
# 1     1538572958.715995  Cbetl72NeXczaqQ8Lj  192.168.100.113  60546
# 2     1538572982.666603  CUmQWl2ZA2hrbNtohe  192.168.100.113  37320
# 3     1538572992.677145   C9oEZWtG35wx1Mqq5  192.168.100.113  51338
# 4     1538572992.679377  CbhqpU1oZZyrP7PE6i  192.168.100.113  60088
# ...                 ...                 ...              ...    ...
# 3281  1538658604.666507  Co564F1QNSoTE46mad  192.168.100.113    123
# 3282  1538658812.666424  CsqptL3U3IopamCGQ6  192.168.100.113    123
# 3283  1538658859.666630  CM1PRb4VLsTg6NwpP3  192.168.100.113    123
# 3284  1538659000.666495   CHg7OGn02ubAXL4Fc  192.168.100.113    123
# 3285  1538636961.823246  CJ0N5q2qFD0t1nCl3j  192.168.100.113  41186
#
#                   4    5    6    7             8      9   ...  11 12 13    14  \
# 0      192.168.100.1   53  udp  dns             -      -  ...  S0  -  -     0
# 1      192.168.100.1   53  udp  dns      0.001494     90  ...  SF  -  -     0
# 2      192.168.100.1   53  udp  dns      5.005135     78  ...  S0  -  -     0
# 3      192.168.100.1   53  udp  dns      0.001483     90  ...  SF  -  -     0
# 4      192.168.100.1   53  udp  dns      5.038625    117  ...  SF  -  -     0
# ...              ...  ...  ...  ...           ...    ...  ...  .. .. ..   ...
# 3281  213.199.225.40  123  udp    -             -      -  ...  S0  -  -     0
# 3282   89.221.212.46  123  udp    -             -      -  ...  S0  -  -     0
# 3283   77.78.107.252  123  udp    -      0.001990     48  ...  SF  -  -     0
# 3284     81.2.254.32  123  udp    -             -      -  ...  S0  -  -     0
# 3285    66.85.157.90  443  tcp    -  22388.393741  12183  ...  S1  -  -  2472
#
#              15    16      17    18      19                         20
# 0             D     1      67     0       0             -   Benign   -
# 1            Dd     2     146     2     146             -   Benign   -
# 2             D     2     134     0       0             -   Benign   -
# 3            Dd     2     146     2     146             -   Benign   -
# 4            Dd     3     201     2     198             -   Benign   -
# ...         ...   ...     ...   ...     ...                        ...
# 3281          D     1      76     0       0             -   Benign   -
# 3282          D     1      76     0       0             -   Benign   -
# 3283         Dd     1      76     1      76             -   Benign   -
# 3284          D     1      76     0       0             -   Benign   -
# 3285  ShADaCGdt  4485  189231  4702  200386  -   Malicious   C&C-Torii
#
# [3286 rows x 21 columns]

# %%
df[20].values[1:100]
# Out:
# array(['-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Malicious   C&C-Torii', '-   Benign   -',
#        '-   Malicious   C&C-Torii', '-   Benign   -', '-   Benign   -',
#        '-   Malicious   C&C-Torii', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -'], dtype=object)

# %%
x
# Out:
# ['#fields',
#  'ts',
#  'uid',
#  'id.orig_h',
#  'id.orig_p',
#  'id.resp_h',
#  'id.resp_p',
#  'proto',
#  'service',
#  'duration',
#  'orig_bytes',
#  'resp_bytes',
#  'conn_state',
#  'local_orig',
#  'local_resp',
#  'missed_bytes',
#  'history',
#  'orig_pkts',
#  'orig_ip_bytes',
#  'resp_pkts',
#  'resp_ip_bytes',
#  'tunnel_parents   label   detailed-label\n']

# %%
x.pop(0)
# Out:
# '#fields'

# %%
x[20]='tunnel_parents   label   detailed-label'

# %%
x
# Out:
# ['ts',
#  'uid',
#  'id.orig_h',
#  'id.orig_p',
#  'id.resp_h',
#  'id.resp_p',
#  'proto',
#  'service',
#  'duration',
#  'orig_bytes',
#  'resp_bytes',
#  'conn_state',
#  'local_orig',
#  'local_resp',
#  'missed_bytes',
#  'history',
#  'orig_pkts',
#  'orig_ip_bytes',
#  'resp_pkts',
#  'resp_ip_bytes',
#  'tunnel_parents   label   detailed-label']

# %%
df.columns=x

# %%
df
# Out:
#                      ts                 uid        id.orig_h id.orig_p  \
# 0     1538572953.710599   Cu3Tieri43IPsyBO3  192.168.100.113     42789
# 1     1538572958.715995  Cbetl72NeXczaqQ8Lj  192.168.100.113     60546
# 2     1538572982.666603  CUmQWl2ZA2hrbNtohe  192.168.100.113     37320
# 3     1538572992.677145   C9oEZWtG35wx1Mqq5  192.168.100.113     51338
# 4     1538572992.679377  CbhqpU1oZZyrP7PE6i  192.168.100.113     60088
# ...                 ...                 ...              ...       ...
# 3281  1538658604.666507  Co564F1QNSoTE46mad  192.168.100.113       123
# 3282  1538658812.666424  CsqptL3U3IopamCGQ6  192.168.100.113       123
# 3283  1538658859.666630  CM1PRb4VLsTg6NwpP3  192.168.100.113       123
# 3284  1538659000.666495   CHg7OGn02ubAXL4Fc  192.168.100.113       123
# 3285  1538636961.823246  CJ0N5q2qFD0t1nCl3j  192.168.100.113     41186
#
#            id.resp_h id.resp_p proto service      duration orig_bytes  ...  \
# 0      192.168.100.1        53   udp     dns             -          -  ...
# 1      192.168.100.1        53   udp     dns      0.001494         90  ...
# 2      192.168.100.1        53   udp     dns      5.005135         78  ...
# 3      192.168.100.1        53   udp     dns      0.001483         90  ...
# 4      192.168.100.1        53   udp     dns      5.038625        117  ...
# ...              ...       ...   ...     ...           ...        ...  ...
# 3281  213.199.225.40       123   udp       -             -          -  ...
# 3282   89.221.212.46       123   udp       -             -          -  ...
# 3283   77.78.107.252       123   udp       -      0.001990         48  ...
# 3284     81.2.254.32       123   udp       -             -          -  ...
# 3285    66.85.157.90       443   tcp       -  22388.393741      12183  ...
#
#      conn_state local_orig local_resp missed_bytes    history orig_pkts  \
# 0            S0          -          -            0          D         1
# 1            SF          -          -            0         Dd         2
# 2            S0          -          -            0          D         2
# 3            SF          -          -            0         Dd         2
# 4            SF          -          -            0         Dd         3
# ...         ...        ...        ...          ...        ...       ...
# 3281         S0          -          -            0          D         1
# 3282         S0          -          -            0          D         1
# 3283         SF          -          -            0         Dd         1
# 3284         S0          -          -            0          D         1
# 3285         S1          -          -         2472  ShADaCGdt      4485
#
#      orig_ip_bytes resp_pkts resp_ip_bytes  \
# 0               67         0             0
# 1              146         2           146
# 2              134         0             0
# 3              146         2           146
# 4              201         2           198
# ...            ...       ...           ...
# 3281            76         0             0
# 3282            76         0             0
# 3283            76         1            76
# 3284            76         0             0
# 3285        189231      4702        200386
#
#      tunnel_parents   label   detailed-label
# 0                             -   Benign   -
# 1                             -   Benign   -
# 2                             -   Benign   -
# 3                             -   Benign   -
# 4                             -   Benign   -
# ...                                      ...
# 3281                          -   Benign   -
# 3282                          -   Benign   -
# 3283                          -   Benign   -
# 3284                          -   Benign   -
# 3285               -   Malicious   C&C-Torii
#
# [3286 rows x 21 columns]

# %%
df.to_csv("21.csv")
