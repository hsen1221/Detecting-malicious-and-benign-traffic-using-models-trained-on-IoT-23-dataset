# %%
import numpy as np
import pandas as pd
# Assign the filename
fpath = r"60conn.log.labeled"
# Import file using np.recfromcsv: d
narray = np.recfromcsv(fpath, encoding=None)

# Print out first n records of d 
print(narray)
# string to search in file
word = 'fields'
with open(fpath, 'r') as fp:
    # read all lines in a list
    lines = fp.readlines()
    for line in lines:
        # check if string present on a current line
        if line.find(word) != -1:
            print(word, 'string exists in file')
            print('Line Number:', lines.index(line))
            print('Line:', line)
            linefields = line
x = linefields.split("\t")
df = pd.concat([pd.Series(l.astype(str).split('\t')) for l in narray], axis=1).T
print(df)
# Out:
# [('1568940058.775322\tCEjjLs1iwWYrt8C4O6\t192.168.1.195\t123\t212.111.30.190\t123\tudp\t-\t0.008239\t96\t96\tSF\t-\t-\t0\tDd\t2\t152\t2\t152\t-   Benign   -',)
#  ('1568940119.775273\tCHNzmm3tMu5Gse9Zvg\t192.168.1.195\t123\t89.221.218.101\t123\tudp\t-\t0.007496\t96\t96\tSF\t-\t-\t0\tDd\t2\t152\t2\t152\t-   Benign   -',)
#  ('1568940231.016250\tCDlbowGNUwsHckADd\t192.168.1.195\t37120\t102.165.48.81\t17769\ttcp\t-\t1.848549\t518\t66\tRSTR\t-\t-\t0\tShAdfDr\t10\t1572\t8\t540\t-   Malicious   C&C-HeartBeat',)
#  ...
#  ('1569026390.773122\tChLFLFZumxpFdFbV8\t192.168.1.195\t123\t212.111.30.190\t123\tudp\t-\t0.007994\t96\t96\tSF\t-\t-\t0\tDd\t2\t152\t2\t152\t-   Benign   -',)
#  ('1569026379.773117\tCdOxuh15kV4eHJYKkb\t192.168.1.195\t123\t5.1.56.123\t123\tudp\t-\t0.005250\t96\t96\tSF\t-\t-\t0\tDd\t2\t152\t2\t152\t-   Benign   -',)
#  ('1569026382.773052\tC7q9EgOTCtbdacBK3\t192.168.1.195\t123\t81.2.254.32\t123\tudp\t-\t0.005497\t96\t96\tSF\t-\t-\t0\tDd\t2\t152\t2\t152\t-   Benign   -',)]
# ...

# %%
display(df)
# Out:
#                         0                   1              2      3   \
# 0        1568940058.775322  CEjjLs1iwWYrt8C4O6  192.168.1.195    123
# 1        1568940119.775273  CHNzmm3tMu5Gse9Zvg  192.168.1.195    123
# 2        1568940231.016250   CDlbowGNUwsHckADd  192.168.1.195  37120
# 3        1568940041.665907  CxKxhj4MGsf5GcqoX6    192.168.1.1  47805
# 4        1568940251.392718  C2n3PK3bA92hAgTHda  192.168.1.195  37122
# ...                    ...                 ...            ...    ...
# 3581023  1569025923.773211   CyeWQ7K6jWDDbI4Kd  192.168.1.195    123
# 3581024  1568941444.764034  CS9u9p3IiuKuTYfauc  192.168.1.195  37306
# 3581025  1569026390.773122   ChLFLFZumxpFdFbV8  192.168.1.195    123
# 3581026  1569026379.773117  CdOxuh15kV4eHJYKkb  192.168.1.195    123
# 3581027  1569026382.773052   C7q9EgOTCtbdacBK3  192.168.1.195    123
#
#                      4      5    6  7             8     9   ...    11 12 13  \
# ...

# %%
df[20].values[1:100]
# Out:
# array(['-   Benign   -', '-   Malicious   C&C-HeartBeat',
#        '-   Benign   -', '-   Malicious   C&C-HeartBeat',
#        '-   Malicious   C&C-HeartBeat', '-   Malicious   C&C-HeartBeat',
#        '-   Malicious   C&C-HeartBeat', '-   Malicious   C&C-HeartBeat',
#        '-   Malicious   C&C-HeartBeat', '-   Malicious   C&C-HeartBeat',
#        '-   Benign   -', '-   Malicious   C&C-HeartBeat',
#        '-   Malicious   C&C-HeartBeat', '-   Malicious   C&C-HeartBeat',
#        '-   Malicious   C&C-HeartBeat', '-   Malicious   C&C-HeartBeat',
#        '-   Malicious   C&C-HeartBeat', '-   Malicious   C&C-HeartBeat',
#        '-   Malicious   C&C-HeartBeat', '-   Malicious   C&C-HeartBeat',
#        '-   Malicious   C&C-HeartBeat', '-   Malicious   C&C-HeartBeat',
#        '-   Malicious   C&C-HeartBeat', '-   Malicious   C&C-HeartBeat',
#        '-   Malicious   C&C-HeartBeat', '-   Malicious   C&C-HeartBeat',
# ...

# %%
x
# Out:
# ['#fields',
#  'ts',
#  'uid',
#  'id.orig_h',
#  'id.orig_p',
#  'id.resp_h',
#  'id.resp_p',
#  'proto',
#  'service',
#  'duration',
#  'orig_bytes',
#  'resp_bytes',
#  'conn_state',
#  'local_orig',
#  'local_resp',
#  'missed_bytes',
#  'history',
#  'orig_pkts',
#  'orig_ip_bytes',
#  'resp_pkts',
#  'resp_ip_bytes',
#  'tunnel_parents   label   detailed-label\n']

# %%
x.pop(0)
# Out:
# '#fields'

# %%
x[20]='tunnel_parents   label   detailed-label'

# %%
x
# Out:
# ['ts',
#  'uid',
#  'id.orig_h',
#  'id.orig_p',
#  'id.resp_h',
#  'id.resp_p',
#  'proto',
#  'service',
#  'duration',
#  'orig_bytes',
#  'resp_bytes',
#  'conn_state',
#  'local_orig',
#  'local_resp',
#  'missed_bytes',
#  'history',
#  'orig_pkts',
#  'orig_ip_bytes',
#  'resp_pkts',
#  'resp_ip_bytes',
#  'tunnel_parents   label   detailed-label']

# %%
df.columns=x

# %%
df
# Out:
#                         ts                 uid      id.orig_h id.orig_p  \
# 0        1568940058.775322  CEjjLs1iwWYrt8C4O6  192.168.1.195       123
# 1        1568940119.775273  CHNzmm3tMu5Gse9Zvg  192.168.1.195       123
# 2        1568940231.016250   CDlbowGNUwsHckADd  192.168.1.195     37120
# 3        1568940041.665907  CxKxhj4MGsf5GcqoX6    192.168.1.1     47805
# 4        1568940251.392718  C2n3PK3bA92hAgTHda  192.168.1.195     37122
# ...                    ...                 ...            ...       ...
# 3581023  1569025923.773211   CyeWQ7K6jWDDbI4Kd  192.168.1.195       123
# 3581024  1568941444.764034  CS9u9p3IiuKuTYfauc  192.168.1.195     37306
# 3581025  1569026390.773122   ChLFLFZumxpFdFbV8  192.168.1.195       123
# 3581026  1569026379.773117  CdOxuh15kV4eHJYKkb  192.168.1.195       123
# 3581027  1569026382.773052   C7q9EgOTCtbdacBK3  192.168.1.195       123
#
#               id.resp_h id.resp_p proto service      duration orig_bytes  ...  \
# ...

# %%
import pandas as pd
import re
import csv

# Assuming df is your DataFrame loaded in Jupyter

# 1. Clean column names
def clean_column_names(df):
    """Standardize column names for CSV export"""
    df.columns = [re.sub(r'\s+', '_', col.strip()).lower() for col in df.columns]
    df.columns = [re.sub(r'[^a-zA-Z0-9_]', '', col) for col in df.columns]
    return df

# Apply cleaning
df = clean_column_names(df)

# 2. Export with proper settings
df.to_csv('60.csv',
          index=False,
          encoding='utf-8-sig',
          quoting=csv.QUOTE_ALL,
          escapechar='\\')

print("CSV exported with clean column names")
# Out:
# CSV exported with clean column names
