# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r"4.csv")

# %%
df
# Out:
#      Unnamed: 0          ts                 uid      id.orig_h  id.orig_p  \
# 0             0  1540469303  CGm6jB4dXK71ZDWUDh  192.168.1.132      58687
# 1             1  1540469197  CnaDAG3n5r8eiG4su2  192.168.1.132       1900
# 2             2  1540469386  CUrxU238nt0m6yTgKf  192.168.1.132      32893
# 3             3  1540469831  CGQf8t1kjdxB5PHXL4  192.168.1.132      53395
# 4             4  1540469831  CUo9DH2QDnCaBIGjkg  192.168.1.132      52801
# ..          ...         ...                 ...            ...        ...
# 447         447  1540547243  CaITg437HfJAXTXZ44  192.168.1.132      53722
# 448         448  1540547243  ChD10Y1fVGrFvMpD6g  192.168.1.132      43799
# 449         449  1540547904  Caxyou4MZpRXfDBG8h  192.168.1.132      51285
# 450         450  1540469198   CkHQfG3B034MyvP3W  192.168.1.132      37653
# 451         451  1540477674  ClZeN63S7LbgEs2ZNk  192.168.1.132       1900
#
#            id.resp_h  id.resp_p proto service     duration  ... conn_state  \
# 0       216.239.35.4        123   udp       -     0.114184  ...         SF
# 1    239.255.255.250       1900   udp       -   160.367579  ...         S0
# 2       216.239.35.8        123   udp       -     0.016986  ...         SF
# 3         2.16.60.82        443   tcp       -     0.003497  ...         SF
# 4        192.168.1.1         53   udp     dns     0.036724  ...         SF
# ..               ...        ...   ...     ...          ...  ...        ...
# 447       2.16.60.82        443   tcp       -     0.011493  ...         SF
# 448      192.168.1.1         53   udp     dns     0.066709  ...         SF
# 449    216.239.35.12        123   udp       -     0.270107  ...         SF
# 450    104.155.18.91        443   tcp       -  78840.32931  ...        OTH
# 451  239.255.255.250       1900   udp       -  70334.10574  ...         S0
#
#     local_orig local_resp missed_bytes history  orig_pkts orig_ip_bytes  \
# 0            -          -            0      Dd          1            76
# 1            -          -            0       D         24          8208
# 2            -          -            0      Dd          1            76
# 3            -          -            0   ShAFf          5           212
# 4            -          -            0      Dd          1            62
# ..         ...        ...          ...     ...        ...           ...
# 447          -          -            0   ShAFf          4           172
# 448          -          -            0      Dd          1            62
# 449          -          -            0      Dd          1            76
# 450          -          -            0    AaDd       3291        157263
# 451          -          -            0       D       8124       2778408
#
#      resp_pkts  resp_ip_bytes  tunnel_parents   label   detailed-label
# 0            1             76                           -   benign   -
# 1            0              0                           -   benign   -
# 2            1             76                           -   benign   -
# 3            3            144                           -   benign   -
# 4            1            339                           -   benign   -
# ..         ...            ...                                      ...
# 447          2             92                           -   benign   -
# 448          1            325                           -   benign   -
# 449          1             76                           -   benign   -
# 450       2667         129675                           -   benign   -
# 451          0              0                           -   benign   -
#
# [452 rows x 22 columns]

# %%
df = df.rename(columns={"tunnel_parents   label   detailed-label": "Label"})
df.drop(df.index[df['Label'] == 'nan'], inplace = True)

# %%
df['Label']=df['Label'].replace('   benign   ','benign')
df['Label']=df['Label'].replace('(empty)   Benign   -','benign')
df['Label']=df['Label'].replace('-   Benign   -','benign')
df['Label']=df['Label'].replace('-   benign   -','benign')
df['Label']=df['Label'].replace('(empty)   benign   -','benign')

# %%
df["Label"].value_counts()
# Out:
# Label
# benign    452
# Name: count, dtype: int64

# %%
# Transform Label column
df['Label'] = np.where(df['Label'] == 'benign', 0, 1)

# %%
df["Label"].value_counts()
# Out:
# Label
# 0    452
# Name: count, dtype: int64

# %%
df
# Out:
#      Unnamed: 0          ts                 uid      id.orig_h  id.orig_p  \
# 0             0  1540469303  CGm6jB4dXK71ZDWUDh  192.168.1.132      58687
# 1             1  1540469197  CnaDAG3n5r8eiG4su2  192.168.1.132       1900
# 2             2  1540469386  CUrxU238nt0m6yTgKf  192.168.1.132      32893
# 3             3  1540469831  CGQf8t1kjdxB5PHXL4  192.168.1.132      53395
# 4             4  1540469831  CUo9DH2QDnCaBIGjkg  192.168.1.132      52801
# ..          ...         ...                 ...            ...        ...
# 447         447  1540547243  CaITg437HfJAXTXZ44  192.168.1.132      53722
# 448         448  1540547243  ChD10Y1fVGrFvMpD6g  192.168.1.132      43799
# 449         449  1540547904  Caxyou4MZpRXfDBG8h  192.168.1.132      51285
# 450         450  1540469198   CkHQfG3B034MyvP3W  192.168.1.132      37653
# 451         451  1540477674  ClZeN63S7LbgEs2ZNk  192.168.1.132       1900
#
#            id.resp_h  id.resp_p proto service     duration  ... conn_state  \
# 0       216.239.35.4        123   udp       -     0.114184  ...         SF
# 1    239.255.255.250       1900   udp       -   160.367579  ...         S0
# 2       216.239.35.8        123   udp       -     0.016986  ...         SF
# 3         2.16.60.82        443   tcp       -     0.003497  ...         SF
# 4        192.168.1.1         53   udp     dns     0.036724  ...         SF
# ..               ...        ...   ...     ...          ...  ...        ...
# 447       2.16.60.82        443   tcp       -     0.011493  ...         SF
# 448      192.168.1.1         53   udp     dns     0.066709  ...         SF
# 449    216.239.35.12        123   udp       -     0.270107  ...         SF
# 450    104.155.18.91        443   tcp       -  78840.32931  ...        OTH
# 451  239.255.255.250       1900   udp       -  70334.10574  ...         S0
#
#     local_orig local_resp missed_bytes history  orig_pkts orig_ip_bytes  \
# 0            -          -            0      Dd          1            76
# 1            -          -            0       D         24          8208
# 2            -          -            0      Dd          1            76
# 3            -          -            0   ShAFf          5           212
# 4            -          -            0      Dd          1            62
# ..         ...        ...          ...     ...        ...           ...
# 447          -          -            0   ShAFf          4           172
# 448          -          -            0      Dd          1            62
# 449          -          -            0      Dd          1            76
# 450          -          -            0    AaDd       3291        157263
# 451          -          -            0       D       8124       2778408
#
#      resp_pkts  resp_ip_bytes  Label
# 0            1             76      0
# 1            0              0      0
# 2            1             76      0
# 3            3            144      0
# 4            1            339      0
# ..         ...            ...    ...
# 447          2             92      0
# 448          1            325      0
# 449          1             76      0
# 450       2667         129675      0
# 451          0              0      0
#
# [452 rows x 22 columns]

# %%
#Encodeing Features
import pandas as pd

# Your predefined encoding dictionary
encoding_map = {
    "proto": {
        "icmp": 0,
        "tcp": 1,
        "udp": 2,
        "UNKNOWN": -1
    },
    "service": {
        "-": 0,
        "dhcp": 1,
        "dns": 2,
        "http": 3,
        "ssh": 4,
        "ssl": 5,
        "irc": 6,
        "UNKNOWN": -1
    },
    "conn_state": {
         "S0": 0,
         "S1": 1,
         "S2": 2,
         "S3": 3,
         "SF": 4,
         "REJ": 5,
         "RSTO": 6,
         "RSTR": 7,
         "RSTOS0": 8,
         "RSTRH": 9,
         "SH": 10,
         "SHR": 11,
         "OTH": 12,
         "UNKNOWN": -1
    }
}

def encode_categorical(df, encoding_map):
    """
    Convert categorical columns in DataFrame to numerical values using the encoding map.
    Unknown values will be mapped to -1.
    """
    for col in encoding_map:
        if col in df.columns:
            df[col] = df[col].map(encoding_map[col]).fillna(-1).astype(int)
    return df

# %%
df= encode_categorical(df, encoding_map)

# %%
df
# Out:
#         Unnamed: 0            ts                 uid    id.orig_h  id.orig_p  \
# 0                0  1.526756e+09  C9YvmJ3zxtuqxWxLW5  192.168.2.5      38792
# 1                1  1.526756e+09  CGsZqZ3UiQexLzPRVb  192.168.2.5      38792
# 2                2  1.526756e+09  C0LkBW2VEa292Nvet8  192.168.2.5      38793
# 3                3  1.526756e+09  CMDLrn2cVhrqvW8gKa  192.168.2.5      38793
# 4                4  1.526756e+09  C2UM8f4knuL5Vnvp3h  192.168.2.5      38794
# ...            ...           ...                 ...          ...        ...
# 156098      156098  1.526886e+09  CzeVGM1n60FIryJyBi  192.168.2.5      36646
# 156099      156099  1.526886e+09   Cq9Oi6YyGNTJlf356  192.168.2.5      36647
# 156100      156100  1.526886e+09  Cc5Jwn4krKLqvFHdG1  192.168.2.5      36647
# 156101      156101  1.526886e+09  Ck8fNL3RpnSPu9Kn9e  192.168.2.5      36648
# 156102      156102  1.526793e+09  CY3eGl3hKYsrYxwFv6  192.168.2.5      41501
#
#              id.resp_h  id.resp_p  proto  service      duration  ...  \
# 0       200.168.87.203      59353      1        0      2.998333  ...
# 1       200.168.87.203      59353      1        0             -  ...
# 2       200.168.87.203      59353      1        0      2.997182  ...
# 3       200.168.87.203      59353      1        0             -  ...
# 4       200.168.87.203      59353      1        0      2.996286  ...
# ...                ...        ...    ...      ...           ...  ...
# 156098  200.168.87.203      59353      1        0             -  ...
# 156099  200.168.87.203      59353      1        0      2.996060  ...
# 156100  200.168.87.203      59353      1        0             -  ...
# 156101  200.168.87.203      59353      1        0      0.995112  ...
# 156102     54.39.23.28       2407      1        6  93280.030966  ...
#
#        conn_state local_orig  local_resp missed_bytes history  orig_pkts  \
# 0               0          -           -            0       S          3
# 1               0          -           -            0       S          1
# 2               0          -           -            0       S          3
# 3               0          -           -            0       S          1
# 4               0          -           -            0       S          3
# ...           ...        ...         ...          ...     ...        ...
# 156098          0          -           -            0       S          1
# 156099          0          -           -            0       S          3
# 156100          0          -           -            0       S          1
# 156101          0          -           -            0       S          2
# 156102          1          -           -            0  ShADad       3031
#
#        orig_ip_bytes  resp_pkts  resp_ip_bytes  Label
# 0                180          0              0      1
# 1                 60          0              0      1
# 2                180          0              0      1
# 3                 60          0              0      1
# 4                180          0              0      1
# ...              ...        ...            ...    ...
# 156098            60          0              0      1
# 156099           180          0              0      1
# 156100            60          0              0      1
# 156101           120          0              0      1
# 156102        164117       5975         289732      1
#
# [156103 rows x 22 columns]

# %%
import pandas as pd
import numpy as np
from scipy.stats import pointbiserialr, chi2_contingency
from sklearn.feature_selection import mutual_info_classif

# Check dtypes
print("Data Types:\n", df.dtypes)
# Out:
# Data Types:
#  Unnamed: 0         int64
# ts               float64
# uid               object
# id.orig_h         object
# id.orig_p          int64
# id.resp_h         object
# id.resp_p          int64
# proto              int32
# service            int32
# duration          object
# orig_bytes        object
# resp_bytes        object
# conn_state         int32
# local_orig        object
# local_resp        object
# missed_bytes       int64
# history           object
# orig_pkts          int64
# orig_ip_bytes      int64
# resp_pkts          int64
# resp_ip_bytes      int64
# Label              int32
# dtype: object

# %%
df = df.drop('Unnamed: 0', axis=1)  
df = df.drop('ts', axis=1)  
df = df.drop('uid', axis=1)  
df = df.drop('local_orig', axis=1)  
df = df.drop('local_resp', axis=1)  
df = df.drop('id.orig_h', axis=1)  
df = df.drop('id.resp_h', axis=1)  
df = df.drop('id.orig_p', axis=1)  
df = df.drop('history', axis=1)

# %%
df.dtypes
# Out:
# id.resp_p         int64
# proto             int32
# service           int32
# duration         object
# orig_bytes       object
# resp_bytes       object
# conn_state        int32
# missed_bytes      int64
# orig_pkts         int64
# orig_ip_bytes     int64
# resp_pkts         int64
# resp_ip_bytes     int64
# Label             int32
# dtype: object

# %%
# Convert "numeric-as-object" columns to float/int
cols_to_convert = ['duration', 'orig_bytes', 'resp_bytes']
df[cols_to_convert] = df[cols_to_convert].apply(pd.to_numeric, errors='coerce')  # 'coerce' sets invalid parsing as NaN

# %%
df.dtypes
# Out:
# id.resp_p          int64
# proto              int32
# service            int32
# duration         float64
# orig_bytes       float64
# resp_bytes       float64
# conn_state         int32
# missed_bytes       int64
# orig_pkts          int64
# orig_ip_bytes      int64
# resp_pkts          int64
# resp_ip_bytes      int64
# Label              int32
# dtype: object

# %%
print(df.dtypes)
# Out:
# id.resp_p          int64
# proto              int32
# service            int32
# duration         float64
# orig_bytes       float64
# resp_bytes       float64
# conn_state         int32
# missed_bytes       int64
# orig_pkts          int64
# orig_ip_bytes      int64
# resp_pkts          int64
# resp_ip_bytes      int64
# Label              int32
# dtype: object

# %%
df
# Out:
#         id.resp_p  proto  service      duration  orig_bytes  resp_bytes  \
# 0           59353      1        0      2.998333         0.0         0.0
# 1           59353      1        0           NaN         NaN         NaN
# 2           59353      1        0      2.997182         0.0         0.0
# 3           59353      1        0           NaN         NaN         NaN
# 4           59353      1        0      2.996286         0.0         0.0
# ...           ...    ...      ...           ...         ...         ...
# 156098      59353      1        0           NaN         NaN         NaN
# 156099      59353      1        0      2.996060         0.0         0.0
# 156100      59353      1        0           NaN         NaN         NaN
# 156101      59353      1        0      0.995112         0.0         0.0
# 156102       2407      1        6  93280.030966      6303.0      9069.0
#
#         conn_state  missed_bytes  orig_pkts  orig_ip_bytes  resp_pkts  \
# 0                0             0          3            180          0
# 1                0             0          1             60          0
# 2                0             0          3            180          0
# 3                0             0          1             60          0
# 4                0             0          3            180          0
# ...            ...           ...        ...            ...        ...
# 156098           0             0          1             60          0
# 156099           0             0          3            180          0
# 156100           0             0          1             60          0
# 156101           0             0          2            120          0
# 156102           1             0       3031         164117       5975
#
#         resp_ip_bytes  Label
# 0                   0      1
# 1                   0      1
# 2                   0      1
# 3                   0      1
# 4                   0      1
# ...               ...    ...
# 156098              0      1
# 156099              0      1
# 156100              0      1
# 156101              0      1
# 156102         289732      1
#
# [156103 rows x 13 columns]

# %%
print(df.dtypes)
# Out:
# id.resp_p          int64
# proto              int32
# service            int32
# duration         float64
# orig_bytes       float64
# resp_bytes       float64
# conn_state         int32
# missed_bytes       int64
# orig_pkts          int64
# orig_ip_bytes      int64
# resp_pkts          int64
# resp_ip_bytes      int64
# Label              int32
# dtype: object

# %%
print(df[['id.resp_p', 'missed_bytes', 'orig_pkts']].describe())
# Out:
#            id.resp_p  missed_bytes      orig_pkts
# count  156103.000000      156103.0  156103.000000
# mean     8876.350698           0.0       2.487620
# std     21140.312518           0.0       8.334926
# min         0.000000           0.0       0.000000
# 25%        22.000000           0.0       1.000000
# 50%        22.000000           0.0       3.000000
# 75%        22.000000           0.0       3.000000
# max     59353.000000           0.0    3031.000000

# %%
df["Label"].value_counts()
# Out:
# Label
# 1    151567
# 0      4536
# Name: count, dtype: int64

# %%
df
# Out:
#         id.resp_p  proto  service      duration  orig_bytes  resp_bytes  \
# 0           59353      1        0      2.998333         0.0         0.0
# 1           59353      1        0           NaN         NaN         NaN
# 2           59353      1        0      2.997182         0.0         0.0
# 3           59353      1        0           NaN         NaN         NaN
# 4           59353      1        0      2.996286         0.0         0.0
# ...           ...    ...      ...           ...         ...         ...
# 156098      59353      1        0           NaN         NaN         NaN
# 156099      59353      1        0      2.996060         0.0         0.0
# 156100      59353      1        0           NaN         NaN         NaN
# 156101      59353      1        0      0.995112         0.0         0.0
# 156102       2407      1        6  93280.030966      6303.0      9069.0
#
#         conn_state  missed_bytes  orig_pkts  orig_ip_bytes  resp_pkts  \
# 0                0             0          3            180          0
# 1                0             0          1             60          0
# 2                0             0          3            180          0
# 3                0             0          1             60          0
# 4                0             0          3            180          0
# ...            ...           ...        ...            ...        ...
# 156098           0             0          1             60          0
# 156099           0             0          3            180          0
# 156100           0             0          1             60          0
# 156101           0             0          2            120          0
# 156102           1             0       3031         164117       5975
#
#         resp_ip_bytes  Label
# 0                   0      1
# 1                   0      1
# 2                   0      1
# 3                   0      1
# 4                   0      1
# ...               ...    ...
# 156098              0      1
# 156099              0      1
# 156100              0      1
# 156101              0      1
# 156102         289732      1
#
# [156103 rows x 13 columns]

# %%
df['Label'].value_counts()
# Out:
# Label
# 1    151567
# 0      4536
# Name: count, dtype: int64

# %%
df['Label'] = df['Label'].dropna()

# %%
df.drop(df.index[df['Label'] == 'nan'], inplace = True)

# %%
df
# Out:
#         id.resp_p  proto  service      duration  orig_bytes  resp_bytes  \
# 0           59353      1        0      2.998333         0.0         0.0
# 1           59353      1        0           NaN         NaN         NaN
# 2           59353      1        0      2.997182         0.0         0.0
# 3           59353      1        0           NaN         NaN         NaN
# 4           59353      1        0      2.996286         0.0         0.0
# ...           ...    ...      ...           ...         ...         ...
# 156098      59353      1        0           NaN         NaN         NaN
# 156099      59353      1        0      2.996060         0.0         0.0
# 156100      59353      1        0           NaN         NaN         NaN
# 156101      59353      1        0      0.995112         0.0         0.0
# 156102       2407      1        6  93280.030966      6303.0      9069.0
#
#         conn_state  missed_bytes  orig_pkts  orig_ip_bytes  resp_pkts  \
# 0                0             0          3            180          0
# 1                0             0          1             60          0
# 2                0             0          3            180          0
# 3                0             0          1             60          0
# 4                0             0          3            180          0
# ...            ...           ...        ...            ...        ...
# 156098           0             0          1             60          0
# 156099           0             0          3            180          0
# 156100           0             0          1             60          0
# 156101           0             0          2            120          0
# 156102           1             0       3031         164117       5975
#
#         resp_ip_bytes  Label
# 0                   0      1
# 1                   0      1
# 2                   0      1
# 3                   0      1
# 4                   0      1
# ...               ...    ...
# 156098              0      1
# 156099              0      1
# 156100              0      1
# 156101              0      1
# 156102         289732      1
#
# [156103 rows x 13 columns]

# %%
import pandas as pd
import numpy as np

# Assuming df is your loaded DataFrame

# Calculate medians for non-S0 connections
non_s0_mask = df['conn_state'] != 0
medians = {
    'duration': df.loc[non_s0_mask, 'duration'].median(),
    'orig_bytes': df.loc[non_s0_mask, 'orig_bytes'].median(),
    'resp_bytes': df.loc[non_s0_mask, 'resp_bytes'].median()
}

# Only fill NaN values where conn_state == 0
for col in ['duration', 'orig_bytes', 'resp_bytes']:
    # For conn_state == 0: Fill ONLY NaNs with 0
    df.loc[(df['conn_state'] == 0) & (df[col].isna()), col] = 0
    
    # For conn_state != 0: Fill NaNs with their respective medians
    df.loc[(df['conn_state'] != 0) & (df[col].isna()), col] = medians[col]

# Verify the results
print("NaN values after imputation:")
print(df[['duration', 'orig_bytes', 'resp_bytes']].isna().sum())
# Out:
# NaN values after imputation:
# duration      0
# orig_bytes    0
# resp_bytes    0
# dtype: int64

# %%
df['Label'].isnull().values.any()
# Out:
# False

# %%
df
# Out:
#         id.resp_p  proto  service      duration  orig_bytes  resp_bytes  \
# 0           59353      1        0      2.998333         0.0         0.0
# 1           59353      1        0      0.000000         0.0         0.0
# 2           59353      1        0      2.997182         0.0         0.0
# 3           59353      1        0      0.000000         0.0         0.0
# 4           59353      1        0      2.996286         0.0         0.0
# ...           ...    ...      ...           ...         ...         ...
# 156098      59353      1        0      0.000000         0.0         0.0
# 156099      59353      1        0      2.996060         0.0         0.0
# 156100      59353      1        0      0.000000         0.0         0.0
# 156101      59353      1        0      0.995112         0.0         0.0
# 156102       2407      1        6  93280.030966      6303.0      9069.0
#
#         conn_state  missed_bytes  orig_pkts  orig_ip_bytes  resp_pkts  \
# 0                0             0          3            180          0
# 1                0             0          1             60          0
# 2                0             0          3            180          0
# 3                0             0          1             60          0
# 4                0             0          3            180          0
# ...            ...           ...        ...            ...        ...
# 156098           0             0          1             60          0
# 156099           0             0          3            180          0
# 156100           0             0          1             60          0
# 156101           0             0          2            120          0
# 156102           1             0       3031         164117       5975
#
#         resp_ip_bytes  Label
# 0                   0      1
# 1                   0      1
# 2                   0      1
# 3                   0      1
# 4                   0      1
# ...               ...    ...
# 156098              0      1
# 156099              0      1
# 156100              0      1
# 156101              0      1
# 156102         289732      1
#
# [156103 rows x 13 columns]

# %%
import pandas as pd

# Check for NaN values in the current DataFrame
nan_check = df.isna().sum()

# Filter to only show columns with NaN values
nan_columns = nan_check[nan_check > 0]

if nan_columns.empty:
    print("No NaN values found in the DataFrame")
else:
    print("Columns with NaN values and their counts:")
    for col, count in nan_columns.items():
        print(f"- {col}: {count} NaN values")
    
    print(f"\nTotal NaN values in DataFrame: {nan_check.sum()}")
# Out:
# No NaN values found in the DataFrame

# %%
df['missed_bytes'] = df['missed_bytes'].fillna(0)

# %%
df.to_csv(r"4cleaned.csv",index=False)
