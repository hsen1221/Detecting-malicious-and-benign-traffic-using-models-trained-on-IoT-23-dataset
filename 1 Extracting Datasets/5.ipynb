# %%
import numpy as np
import pandas as pd
# Assign the filename
fpath = r"5conn.log.labeled"
# Import file using np.recfromcsv: d
narray = np.recfromcsv(fpath, encoding=None)

# Print out first n records of d 
print(narray)
# string to search in file
word = 'fields'
with open(fpath, 'r') as fp:
    # read all lines in a list
    lines = fp.readlines()
    for line in lines:
        # check if string present on a current line
        if line.find(word) != -1:
            print(word, 'string exists in file')
            print('Line Number:', lines.index(line))
            print('Line:', line)
            linefields = line
x = linefields.split("\t")
df = pd.concat([pd.Series(l.astype(str).split('\t')) for l in narray], axis=1).T
print(df)
# Out:
# [('1537522822.965530\tCJAF5z3MDFg4XVDXB\t0.0.0.0\t68\t255.255.255.255\t67\tudp\tdhcp\t8.322388\t600\t0\tS0\t-\t-\t0\tD\t2\t656\t0\t0\t-   benign   -',)
#  ('1537522897.732295\tCcYEFX3Qj9xdNX1ZCa\t192.168.2.1\t5353\t224.0.0.251\t5353\tudp\tdns\t-\t-\t-\tS0\t-\t-\t0\tD\t1\t391\t0\t0\t-   benign   -',)
#  ('1537522897.732374\tCF6fCK1nFqvI1XxGM1\tfe80::80e6:50ff:fe12:1464\t5353\tff02::fb\t5353\tudp\tdns\t-\t-\t-\tS0\t-\t-\t0\tD\t1\t411\t0\t0\t-   benign   -',)
#  ...
#  ('1537542535.379473\tCdWSpn4EA2vXfUBqI7\tfe80::183b:7564:dbcc:3eca\t143\tff02::16\t0\ticmp\t-\t1.024087\t40\t0\tOTH\t-\t-\t0\t-\t2\t152\t0\t0\t-   benign   -',)
#  ('1537542504.559192\tClKCqX3JOxjrti9lLh\tfe80::1847:a1bd:8d13:f43c\t143\tff02::16\t0\ticmp\t-\t59.390351\t80\t0\tOTH\t-\t-\t0\t-\t4\t304\t0\t0\t-   benign   -',)
#  ('1537542573.267978\tCDsdf81FPzUzFBBRBe\tfe80::1c5c:213d:7cf8:890\t143\tff02::16\t0\ticmp\t-\t-\t-\t-\tOTH\t-\t-\t0\t-\t1\t76\t0\t0\t-   benign   -',)]
# fields string exists in file
# Line Number: 6
# Line: #fields	ts	uid	id.orig_h	id.orig_p	id.resp_h	id.resp_p	proto	service	duration	orig_bytes	resp_bytes	conn_state	local_orig	local_resp	missed_bytes	history	orig_pkts	orig_ip_bytes	resp_pkts	resp_ip_bytes	tunnel_parents   label   detailed-label
#
#                      0                   1                          2      3   \
# 0     1537522822.965530   CJAF5z3MDFg4XVDXB                    0.0.0.0     68
# 1     1537522897.732295  CcYEFX3Qj9xdNX1ZCa                192.168.2.1   5353
# 2     1537522897.732374  CF6fCK1nFqvI1XxGM1  fe80::80e6:50ff:fe12:1464   5353
# 3     1537522897.732507  C2dlio3MkdwWJ80y04             169.254.15.115   5353
# 4     1537522899.498805  COrF0t2uLErai9nfH5                    0.0.0.0     68
# ...                 ...                 ...                        ...    ...
# 1369  1537542534.223382  CrPQ4n1jVFxbm0mcj9             192.168.69.136  51443
# 1370  1537542560.979740  Ce0LkH33VlZBF8Vw93   fe80::106c:9e5b:3af8:9cf    143
# 1371  1537542535.379473  CdWSpn4EA2vXfUBqI7  fe80::183b:7564:dbcc:3eca    143
# 1372  1537542504.559192  ClKCqX3JOxjrti9lLh  fe80::1847:a1bd:8d13:f43c    143
# 1373  1537542573.267978  CDsdf81FPzUzFBBRBe   fe80::1c5c:213d:7cf8:890    143
#
#                    4     5     6     7          8     9   ...   11 12 13 14  \
# 0     255.255.255.255    67   udp  dhcp   8.322388   600  ...   S0  -  -  0
# 1         224.0.0.251  5353   udp   dns          -     -  ...   S0  -  -  0
# 2            ff02::fb  5353   udp   dns          -     -  ...   S0  -  -  0
# 3         224.0.0.251  5353   udp   dns          -     -  ...   S0  -  -  0
# 4     255.255.255.255    67   udp  dhcp  60.555587  3000  ...   S0  -  -  0
# ...               ...   ...   ...   ...        ...   ...  ...  ... .. .. ..
# 1369  239.255.255.250  1900   udp     -          -     -  ...   S0  -  -  0
# 1370         ff02::16     0  icmp     -   1.945701    40  ...  OTH  -  -  0
# 1371         ff02::16     0  icmp     -   1.024087    40  ...  OTH  -  -  0
# 1372         ff02::16     0  icmp     -  59.390351    80  ...  OTH  -  -  0
# 1373         ff02::16     0  icmp     -          -     -  ...  OTH  -  -  0
#
#      15  16    17 18 19              20
# 0     D   2   656  0  0  -   benign   -
# 1     D   1   391  0  0  -   benign   -
# 2     D   1   411  0  0  -   benign   -
# 3     D   1   391  0  0  -   benign   -
# 4     D  10  3280  0  0  -   benign   -
# ...  ..  ..   ... .. ..             ...
# 1369  D   1   153  0  0  -   benign   -
# 1370  -   2   152  0  0  -   benign   -
# 1371  -   2   152  0  0  -   benign   -
# 1372  -   4   304  0  0  -   benign   -
# 1373  -   1    76  0  0  -   benign   -
#
# [1374 rows x 21 columns]

# %%
display(df)
# Out:
#                      0                   1                          2      3   \
# 0     1537522822.965530   CJAF5z3MDFg4XVDXB                    0.0.0.0     68
# 1     1537522897.732295  CcYEFX3Qj9xdNX1ZCa                192.168.2.1   5353
# 2     1537522897.732374  CF6fCK1nFqvI1XxGM1  fe80::80e6:50ff:fe12:1464   5353
# 3     1537522897.732507  C2dlio3MkdwWJ80y04             169.254.15.115   5353
# 4     1537522899.498805  COrF0t2uLErai9nfH5                    0.0.0.0     68
# ...                 ...                 ...                        ...    ...
# 1369  1537542534.223382  CrPQ4n1jVFxbm0mcj9             192.168.69.136  51443
# 1370  1537542560.979740  Ce0LkH33VlZBF8Vw93   fe80::106c:9e5b:3af8:9cf    143
# 1371  1537542535.379473  CdWSpn4EA2vXfUBqI7  fe80::183b:7564:dbcc:3eca    143
# 1372  1537542504.559192  ClKCqX3JOxjrti9lLh  fe80::1847:a1bd:8d13:f43c    143
# 1373  1537542573.267978  CDsdf81FPzUzFBBRBe   fe80::1c5c:213d:7cf8:890    143
#
#                    4     5     6     7          8     9   ...   11 12 13 14  \
# 0     255.255.255.255    67   udp  dhcp   8.322388   600  ...   S0  -  -  0
# 1         224.0.0.251  5353   udp   dns          -     -  ...   S0  -  -  0
# 2            ff02::fb  5353   udp   dns          -     -  ...   S0  -  -  0
# 3         224.0.0.251  5353   udp   dns          -     -  ...   S0  -  -  0
# 4     255.255.255.255    67   udp  dhcp  60.555587  3000  ...   S0  -  -  0
# ...               ...   ...   ...   ...        ...   ...  ...  ... .. .. ..
# 1369  239.255.255.250  1900   udp     -          -     -  ...   S0  -  -  0
# 1370         ff02::16     0  icmp     -   1.945701    40  ...  OTH  -  -  0
# 1371         ff02::16     0  icmp     -   1.024087    40  ...  OTH  -  -  0
# 1372         ff02::16     0  icmp     -  59.390351    80  ...  OTH  -  -  0
# 1373         ff02::16     0  icmp     -          -     -  ...  OTH  -  -  0
#
#      15  16    17 18 19              20
# 0     D   2   656  0  0  -   benign   -
# 1     D   1   391  0  0  -   benign   -
# 2     D   1   411  0  0  -   benign   -
# 3     D   1   391  0  0  -   benign   -
# 4     D  10  3280  0  0  -   benign   -
# ...  ..  ..   ... .. ..             ...
# 1369  D   1   153  0  0  -   benign   -
# 1370  -   2   152  0  0  -   benign   -
# 1371  -   2   152  0  0  -   benign   -
# 1372  -   4   304  0  0  -   benign   -
# 1373  -   1    76  0  0  -   benign   -
#
# [1374 rows x 21 columns]

# %%
df[20].values[1:100]
# Out:
# array(['-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -',
#        '-   benign   -', '-   benign   -', '-   benign   -'], dtype=object)

# %%
x
# Out:
# ['#fields',
#  'ts',
#  'uid',
#  'id.orig_h',
#  'id.orig_p',
#  'id.resp_h',
#  'id.resp_p',
#  'proto',
#  'service',
#  'duration',
#  'orig_bytes',
#  'resp_bytes',
#  'conn_state',
#  'local_orig',
#  'local_resp',
#  'missed_bytes',
#  'history',
#  'orig_pkts',
#  'orig_ip_bytes',
#  'resp_pkts',
#  'resp_ip_bytes',
#  'tunnel_parents   label   detailed-label\n']

# %%
x.pop(0)
# Out:
# '#fields'

# %%
x[20]='tunnel_parents   label   detailed-label'

# %%
x
# Out:
# ['ts',
#  'uid',
#  'id.orig_h',
#  'id.orig_p',
#  'id.resp_h',
#  'id.resp_p',
#  'proto',
#  'service',
#  'duration',
#  'orig_bytes',
#  'resp_bytes',
#  'conn_state',
#  'local_orig',
#  'local_resp',
#  'missed_bytes',
#  'history',
#  'orig_pkts',
#  'orig_ip_bytes',
#  'resp_pkts',
#  'resp_ip_bytes',
#  'tunnel_parents   label   detailed-label']

# %%
df.columns=x

# %%
df
# Out:
#                      ts                 uid                  id.orig_h  \
# 0     1537522822.965530   CJAF5z3MDFg4XVDXB                    0.0.0.0
# 1     1537522897.732295  CcYEFX3Qj9xdNX1ZCa                192.168.2.1
# 2     1537522897.732374  CF6fCK1nFqvI1XxGM1  fe80::80e6:50ff:fe12:1464
# 3     1537522897.732507  C2dlio3MkdwWJ80y04             169.254.15.115
# 4     1537522899.498805  COrF0t2uLErai9nfH5                    0.0.0.0
# ...                 ...                 ...                        ...
# 1369  1537542534.223382  CrPQ4n1jVFxbm0mcj9             192.168.69.136
# 1370  1537542560.979740  Ce0LkH33VlZBF8Vw93   fe80::106c:9e5b:3af8:9cf
# 1371  1537542535.379473  CdWSpn4EA2vXfUBqI7  fe80::183b:7564:dbcc:3eca
# 1372  1537542504.559192  ClKCqX3JOxjrti9lLh  fe80::1847:a1bd:8d13:f43c
# 1373  1537542573.267978  CDsdf81FPzUzFBBRBe   fe80::1c5c:213d:7cf8:890
#
#      id.orig_p        id.resp_h id.resp_p proto service   duration orig_bytes  \
# 0           68  255.255.255.255        67   udp    dhcp   8.322388        600
# 1         5353      224.0.0.251      5353   udp     dns          -          -
# 2         5353         ff02::fb      5353   udp     dns          -          -
# 3         5353      224.0.0.251      5353   udp     dns          -          -
# 4           68  255.255.255.255        67   udp    dhcp  60.555587       3000
# ...        ...              ...       ...   ...     ...        ...        ...
# 1369     51443  239.255.255.250      1900   udp       -          -          -
# 1370       143         ff02::16         0  icmp       -   1.945701         40
# 1371       143         ff02::16         0  icmp       -   1.024087         40
# 1372       143         ff02::16         0  icmp       -  59.390351         80
# 1373       143         ff02::16         0  icmp       -          -          -
#
#       ... conn_state local_orig local_resp missed_bytes history orig_pkts  \
# 0     ...         S0          -          -            0       D         2
# 1     ...         S0          -          -            0       D         1
# 2     ...         S0          -          -            0       D         1
# 3     ...         S0          -          -            0       D         1
# 4     ...         S0          -          -            0       D        10
# ...   ...        ...        ...        ...          ...     ...       ...
# 1369  ...         S0          -          -            0       D         1
# 1370  ...        OTH          -          -            0       -         2
# 1371  ...        OTH          -          -            0       -         2
# 1372  ...        OTH          -          -            0       -         4
# 1373  ...        OTH          -          -            0       -         1
#
#      orig_ip_bytes resp_pkts resp_ip_bytes  \
# 0              656         0             0
# 1              391         0             0
# 2              411         0             0
# 3              391         0             0
# 4             3280         0             0
# ...            ...       ...           ...
# 1369           153         0             0
# 1370           152         0             0
# 1371           152         0             0
# 1372           304         0             0
# 1373            76         0             0
#
#      tunnel_parents   label   detailed-label
# 0                             -   benign   -
# 1                             -   benign   -
# 2                             -   benign   -
# 3                             -   benign   -
# 4                             -   benign   -
# ...                                      ...
# 1369                          -   benign   -
# 1370                          -   benign   -
# 1371                          -   benign   -
# 1372                          -   benign   -
# 1373                          -   benign   -
#
# [1374 rows x 21 columns]

# %%
df.to_csv("5.csv")
