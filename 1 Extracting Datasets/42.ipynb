# %%
import numpy as np
import pandas as pd
# Assign the filename
fpath = r"42conn.log.labeled"
# Import file using np.recfromcsv: d
narray = np.recfromcsv(fpath, encoding=None)

# Print out first n records of d 
print(narray)
# string to search in file
word = 'fields'
with open(fpath, 'r') as fp:
    # read all lines in a list
    lines = fp.readlines()
    for line in lines:
        # check if string present on a current line
        if line.find(word) != -1:
            print(word, 'string exists in file')
            print('Line Number:', lines.index(line))
            print('Line:', line)
            linefields = line
x = linefields.split("\t")
df = pd.concat([pd.Series(l.astype(str).split('\t')) for l in narray], axis=1).T
print(df)
# Out:
# [('1547127288.026074\tCXY5uG2sSmjJ0grfY2\t192.168.1.197\t58312\t104.24.96.120\t80\ttcp\thttp\t3.909013\t83\t67212\tSF\t-\t-\t4380\tShADadttFf\t54\t3371\t50\t69224\t-   Malicious   FileDownload',)
#  ('1547127288.018828\tCe3AJzwzXwM3Z1XBg\t192.168.1.197\t45082\t104.24.97.120\t80\ttcp\thttp\t4.767024\t150\t67212\tSF\t-\t-\t0\tShADadttFf\t54\t2938\t50\t69224\t-   Malicious   C&C-FileDownload',)
#  ('1547127292.857808\tCJgnSb3XpbbOcMHKUd\t192.168.1.197\t58316\t104.24.96.120\t80\ttcp\t-\t3.107228\t0\t0\tS0\t-\t-\t0\tS\t3\t180\t0\t0\t-   Benign   -',)
#  ...
#  ('1547156922.030682\tCcvd9l4NjDPEkD1nRd\t192.168.1.197\t123\t81.2.248.189\t123\tudp\t-\t0.005252\t48\t48\tSF\t-\t-\t0\tDd\t1\t76\t1\t76\t-   Benign   -',)
#  ('1547127351.088982\tC07GbT1HxlFUEjwiNh\t185.244.25.183\t4975\t192.168.1.197\t50516\ttcp\t-\t30007.122211\t8499\t8025\tOTH\t-\t-\t0\tDdAa\t654\t42791\t348\t26493\t-   Benign   -',)
#  ('1547157330.030005\tCb4VXV3tOHGjcsI0cf\t192.168.1.197\t123\t82.113.53.40\t123\tudp\t-\t-\t-\t-\tS0\t-\t-\t0\tD\t1\t76\t0\t0\t-   Benign   -',)]
# fields string exists in file
# Line Number: 6
# Line: #fields	ts	uid	id.orig_h	id.orig_p	id.resp_h	id.resp_p	proto	service	duration	orig_bytes	resp_bytes	conn_state	local_orig	local_resp	missed_bytes	history	orig_pkts	orig_ip_bytes	resp_pkts	resp_ip_bytes	tunnel_parents   label   detailed-label
#
#                      0                   1               2      3   \
# 0     1547127288.026074  CXY5uG2sSmjJ0grfY2   192.168.1.197  58312
# 1     1547127288.018828   Ce3AJzwzXwM3Z1XBg   192.168.1.197  45082
# 2     1547127292.857808  CJgnSb3XpbbOcMHKUd   192.168.1.197  58316
# 3     1547127287.987598   Cq43w4aHlsW8nXZ3l   192.168.1.197  59357
# 4     1547127288.023327  C5uLwl2hGy10y9PSr6   192.168.1.197  39686
# ...                 ...                 ...             ...    ...
# 4421  1547156277.011183  Cg18Jr15pQhdJUELL4   192.168.1.197    123
# 4422  1547156435.011502  CF56fv3yDg2vRnegKa   192.168.1.197    123
# 4423  1547156922.030682  Ccvd9l4NjDPEkD1nRd   192.168.1.197    123
# 4424  1547127351.088982  C07GbT1HxlFUEjwiNh  185.244.25.183   4975
# 4425  1547157330.030005  Cb4VXV3tOHGjcsI0cf   192.168.1.197    123
#
#                   4      5    6     7             8     9   ...   11 12 13  \
# 0      104.24.96.120     80  tcp  http      3.909013    83  ...   SF  -  -
# 1      104.24.97.120     80  tcp  http      4.767024   150  ...   SF  -  -
# 2      104.24.96.120     80  tcp     -      3.107228     0  ...   S0  -  -
# 3        192.168.1.1     53  udp   dns      0.029483    58  ...   SF  -  -
# 4        192.168.1.1     53  udp   dns      0.001249    58  ...   SF  -  -
# ...              ...    ...  ...   ...           ...   ...  ...  ... .. ..
# 4421    82.113.53.40    123  udp     -             -     -  ...   S0  -  -
# 4422  89.221.214.130    123  udp     -      0.003995    48  ...   SF  -  -
# 4423    81.2.248.189    123  udp     -      0.005252    48  ...   SF  -  -
# 4424   192.168.1.197  50516  tcp     -  30007.122211  8499  ...  OTH  -  -
# 4425    82.113.53.40    123  udp     -             -     -  ...   S0  -  -
#
#         14          15   16     17   18     19  \
# 0     4380  ShADadttFf   54   3371   50  69224
# 1        0  ShADadttFf   54   2938   50  69224
# 2        0           S    3    180    0      0
# 3        0          Dd    2    114    2    202
# 4        0          Dd    2    114    2    202
# ...    ...         ...  ...    ...  ...    ...
# 4421     0           D    1     76    0      0
# 4422     0          Dd    1     76    1     76
# 4423     0          Dd    1     76    1     76
# 4424     0        DdAa  654  42791  348  26493
# 4425     0           D    1     76    0      0
#
#                                     20
# 0         -   Malicious   FileDownload
# 1     -   Malicious   C&C-FileDownload
# 2                       -   Benign   -
# 3                       -   Benign   -
# 4                       -   Benign   -
# ...                                ...
# 4421                    -   Benign   -
# 4422                    -   Benign   -
# 4423                    -   Benign   -
# 4424                    -   Benign   -
# 4425                    -   Benign   -
#
# [4426 rows x 21 columns]

# %%
display(df)
# Out:
#                      0                   1               2      3   \
# 0     1547127288.026074  CXY5uG2sSmjJ0grfY2   192.168.1.197  58312
# 1     1547127288.018828   Ce3AJzwzXwM3Z1XBg   192.168.1.197  45082
# 2     1547127292.857808  CJgnSb3XpbbOcMHKUd   192.168.1.197  58316
# 3     1547127287.987598   Cq43w4aHlsW8nXZ3l   192.168.1.197  59357
# 4     1547127288.023327  C5uLwl2hGy10y9PSr6   192.168.1.197  39686
# ...                 ...                 ...             ...    ...
# 4421  1547156277.011183  Cg18Jr15pQhdJUELL4   192.168.1.197    123
# 4422  1547156435.011502  CF56fv3yDg2vRnegKa   192.168.1.197    123
# 4423  1547156922.030682  Ccvd9l4NjDPEkD1nRd   192.168.1.197    123
# 4424  1547127351.088982  C07GbT1HxlFUEjwiNh  185.244.25.183   4975
# 4425  1547157330.030005  Cb4VXV3tOHGjcsI0cf   192.168.1.197    123
#
#                   4      5    6     7             8     9   ...   11 12 13  \
# 0      104.24.96.120     80  tcp  http      3.909013    83  ...   SF  -  -
# 1      104.24.97.120     80  tcp  http      4.767024   150  ...   SF  -  -
# 2      104.24.96.120     80  tcp     -      3.107228     0  ...   S0  -  -
# 3        192.168.1.1     53  udp   dns      0.029483    58  ...   SF  -  -
# 4        192.168.1.1     53  udp   dns      0.001249    58  ...   SF  -  -
# ...              ...    ...  ...   ...           ...   ...  ...  ... .. ..
# 4421    82.113.53.40    123  udp     -             -     -  ...   S0  -  -
# 4422  89.221.214.130    123  udp     -      0.003995    48  ...   SF  -  -
# 4423    81.2.248.189    123  udp     -      0.005252    48  ...   SF  -  -
# 4424   192.168.1.197  50516  tcp     -  30007.122211  8499  ...  OTH  -  -
# 4425    82.113.53.40    123  udp     -             -     -  ...   S0  -  -
#
#         14          15   16     17   18     19  \
# 0     4380  ShADadttFf   54   3371   50  69224
# 1        0  ShADadttFf   54   2938   50  69224
# 2        0           S    3    180    0      0
# 3        0          Dd    2    114    2    202
# 4        0          Dd    2    114    2    202
# ...    ...         ...  ...    ...  ...    ...
# 4421     0           D    1     76    0      0
# 4422     0          Dd    1     76    1     76
# 4423     0          Dd    1     76    1     76
# 4424     0        DdAa  654  42791  348  26493
# 4425     0           D    1     76    0      0
#
#                                     20
# 0         -   Malicious   FileDownload
# 1     -   Malicious   C&C-FileDownload
# 2                       -   Benign   -
# 3                       -   Benign   -
# 4                       -   Benign   -
# ...                                ...
# 4421                    -   Benign   -
# 4422                    -   Benign   -
# 4423                    -   Benign   -
# 4424                    -   Benign   -
# 4425                    -   Benign   -
#
# [4426 rows x 21 columns]

# %%
df[20].values[1:100]
# Out:
# array(['-   Malicious   C&C-FileDownload', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -',
#        '-   Malicious   C&C-FileDownload', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Malicious   FileDownload', '-   Malicious   C&C-FileDownload',
#        '-   Malicious   FileDownload', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -', '-   Benign   -', '-   Benign   -',
#        '-   Benign   -'], dtype=object)

# %%
x
# Out:
# ['#fields',
#  'ts',
#  'uid',
#  'id.orig_h',
#  'id.orig_p',
#  'id.resp_h',
#  'id.resp_p',
#  'proto',
#  'service',
#  'duration',
#  'orig_bytes',
#  'resp_bytes',
#  'conn_state',
#  'local_orig',
#  'local_resp',
#  'missed_bytes',
#  'history',
#  'orig_pkts',
#  'orig_ip_bytes',
#  'resp_pkts',
#  'resp_ip_bytes',
#  'tunnel_parents   label   detailed-label\n']

# %%
x.pop(0)
# Out:
# '#fields'

# %%
x[20]='tunnel_parents   label   detailed-label'

# %%
x
# Out:
# ['ts',
#  'uid',
#  'id.orig_h',
#  'id.orig_p',
#  'id.resp_h',
#  'id.resp_p',
#  'proto',
#  'service',
#  'duration',
#  'orig_bytes',
#  'resp_bytes',
#  'conn_state',
#  'local_orig',
#  'local_resp',
#  'missed_bytes',
#  'history',
#  'orig_pkts',
#  'orig_ip_bytes',
#  'resp_pkts',
#  'resp_ip_bytes',
#  'tunnel_parents   label   detailed-label']

# %%
df.columns=x

# %%
df
# Out:
#                      ts                 uid       id.orig_h id.orig_p  \
# 0     1547127288.026074  CXY5uG2sSmjJ0grfY2   192.168.1.197     58312
# 1     1547127288.018828   Ce3AJzwzXwM3Z1XBg   192.168.1.197     45082
# 2     1547127292.857808  CJgnSb3XpbbOcMHKUd   192.168.1.197     58316
# 3     1547127287.987598   Cq43w4aHlsW8nXZ3l   192.168.1.197     59357
# 4     1547127288.023327  C5uLwl2hGy10y9PSr6   192.168.1.197     39686
# ...                 ...                 ...             ...       ...
# 4421  1547156277.011183  Cg18Jr15pQhdJUELL4   192.168.1.197       123
# 4422  1547156435.011502  CF56fv3yDg2vRnegKa   192.168.1.197       123
# 4423  1547156922.030682  Ccvd9l4NjDPEkD1nRd   192.168.1.197       123
# 4424  1547127351.088982  C07GbT1HxlFUEjwiNh  185.244.25.183      4975
# 4425  1547157330.030005  Cb4VXV3tOHGjcsI0cf   192.168.1.197       123
#
#            id.resp_h id.resp_p proto service      duration orig_bytes  ...  \
# 0      104.24.96.120        80   tcp    http      3.909013         83  ...
# 1      104.24.97.120        80   tcp    http      4.767024        150  ...
# 2      104.24.96.120        80   tcp       -      3.107228          0  ...
# 3        192.168.1.1        53   udp     dns      0.029483         58  ...
# 4        192.168.1.1        53   udp     dns      0.001249         58  ...
# ...              ...       ...   ...     ...           ...        ...  ...
# 4421    82.113.53.40       123   udp       -             -          -  ...
# 4422  89.221.214.130       123   udp       -      0.003995         48  ...
# 4423    81.2.248.189       123   udp       -      0.005252         48  ...
# 4424   192.168.1.197     50516   tcp       -  30007.122211       8499  ...
# 4425    82.113.53.40       123   udp       -             -          -  ...
#
#      conn_state local_orig local_resp missed_bytes     history orig_pkts  \
# 0            SF          -          -         4380  ShADadttFf        54
# 1            SF          -          -            0  ShADadttFf        54
# 2            S0          -          -            0           S         3
# 3            SF          -          -            0          Dd         2
# 4            SF          -          -            0          Dd         2
# ...         ...        ...        ...          ...         ...       ...
# 4421         S0          -          -            0           D         1
# 4422         SF          -          -            0          Dd         1
# 4423         SF          -          -            0          Dd         1
# 4424        OTH          -          -            0        DdAa       654
# 4425         S0          -          -            0           D         1
#
#      orig_ip_bytes resp_pkts resp_ip_bytes  \
# 0             3371        50         69224
# 1             2938        50         69224
# 2              180         0             0
# 3              114         2           202
# 4              114         2           202
# ...            ...       ...           ...
# 4421            76         0             0
# 4422            76         1            76
# 4423            76         1            76
# 4424         42791       348         26493
# 4425            76         0             0
#
#      tunnel_parents   label   detailed-label
# 0               -   Malicious   FileDownload
# 1           -   Malicious   C&C-FileDownload
# 2                             -   Benign   -
# 3                             -   Benign   -
# 4                             -   Benign   -
# ...                                      ...
# 4421                          -   Benign   -
# 4422                          -   Benign   -
# 4423                          -   Benign   -
# 4424                          -   Benign   -
# 4425                          -   Benign   -
#
# [4426 rows x 21 columns]

# %%
df.to_csv("42.csv")
