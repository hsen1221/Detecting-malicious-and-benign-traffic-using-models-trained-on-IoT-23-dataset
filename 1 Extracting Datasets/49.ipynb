# %%
import numpy as np
import pandas as pd
# Assign the filename
fpath = r"49conn.log.labeled"
# Import file using np.recfromcsv: d
narray = np.recfromcsv(fpath, encoding=None)

# Print out first n records of d 
print(narray)
# string to search in file
word = 'fields'
with open(fpath, 'r') as fp:
    # read all lines in a list
    lines = fp.readlines()
    for line in lines:
        # check if string present on a current line
        if line.find(word) != -1:
            print(word, 'string exists in file')
            print('Line Number:', lines.index(line))
            print('Line:', line)
            linefields = line
x = linefields.split("\t")
df = pd.concat([pd.Series(l.astype(str).split('\t')) for l in narray], axis=1).T
print(df)
# Out:
# [('1551383431.142246\tCnkx4U1xJgOIPooe2\t192.168.1.193\t51358\t134.209.72.171\t80\ttcp\thttp\t1.874424\t149\t198998\tSF\t-\t-\t0\tShADadttfF\t234\t12994\t285\t418624\t-   Malicious   FileDownload',)
#  ('1551383433.123797\tC5t6Kp1UnQyH7JCC45\t192.168.1.193\t51360\t134.209.72.171\t80\ttcp\thttp\t1.871487\t151\t198966\tSF\t-\t-\t0\tShADadttfF\t282\t15702\t282\t412612\t-   Malicious   FileDownload',)
#  ('1551383435.092740\tCRdXqi4p3HG1obs6xl\t192.168.1.193\t51362\t134.209.72.171\t80\ttcp\thttp\t2.376374\t148\t140547\tSF\t-\t-\t0\tShADadttfF\t174\t9600\t201\t291562\t-   Malicious   FileDownload',)
#  ...
#  ('1551409625.703405\tC5uG6C4AFRl77HCJM9\t192.168.1.193\t52882\t134.209.72.171\t4554\ttcp\t-\t0.304830\t11\t11\tSF\t-\t-\t0\tShADdfFr\t10\t558\t8\t430\t-   Malicious   C&C',)
#  ('1551409780.796366\tCfdczo4DyzPUejtd0g\t217.229.163.167\t3\t192.168.1.193\t13\ticmp\t-\t0.000005\t56\t0\tOTH\t-\t-\t0\t-\t2\t112\t0\t0\t-   Benign   -',)
#  ('1551409777.981235\tC3W3yA44vwV6ovDa2j\t14.1.5.94\t11\t192.168.1.193\t0\ticmp\t-\t0.000005\t56\t0\tOTH\t-\t-\t0\t-\t2\t112\t0\t0\t-   Benign   -',)]
# fields string exists in file
# Line Number: 6
# Line: #fields	ts	uid	id.orig_h	id.orig_p	id.resp_h	id.resp_p	proto	service	duration	orig_bytes	resp_bytes	conn_state	local_orig	local_resp	missed_bytes	history	orig_pkts	orig_ip_bytes	resp_pkts	resp_ip_bytes	tunnel_parents   label   detailed-label
#
#                         0                   1                2      3   \
# 0        1551383431.142246   Cnkx4U1xJgOIPooe2    192.168.1.193  51358
# 1        1551383433.123797  C5t6Kp1UnQyH7JCC45    192.168.1.193  51360
# 2        1551383435.092740  CRdXqi4p3HG1obs6xl    192.168.1.193  51362
# 3        1551383437.567516  Co7Sfi3KfjPoJwW5Kf    192.168.1.193  51364
# 4        1551383444.739956  CKaKqD34bwvqLUcID9    192.168.1.193  51364
# ...                    ...                 ...              ...    ...
# 5410556  1551409817.668471  Ctc2If2AEpNehSWL2a    192.168.1.193  30535
# 5410557  1551383451.451091   CJm7HCnrDfDREbMm7    192.168.1.193  50178
# 5410558  1551409625.703405  C5uG6C4AFRl77HCJM9    192.168.1.193  52882
# 5410559  1551409780.796366  Cfdczo4DyzPUejtd0g  217.229.163.167      3
# 5410560  1551409777.981235  C3W3yA44vwV6ovDa2j        14.1.5.94     11
#
#                      4     5     6     7             8    9   ...   11 12 13  \
# 0        134.209.72.171    80   tcp  http      1.874424  149  ...   SF  -  -
# 1        134.209.72.171    80   tcp  http      1.871487  151  ...   SF  -  -
# 2        134.209.72.171    80   tcp  http      2.376374  148  ...   SF  -  -
# 3        134.209.72.171    80   tcp     -      3.092539    0  ...   S0  -  -
# 4        134.209.72.171    80   tcp  http      1.359780  148  ...   SF  -  -
# ...                 ...   ...   ...   ...           ...  ...  ...  ... .. ..
# 5410556   217.48.18.213  8081   tcp     -             -    -  ...   S0  -  -
# 5410557  134.209.72.171  4554   tcp     -  26347.422164   11  ...   S1  -  -
# 5410558  134.209.72.171  4554   tcp     -      0.304830   11  ...   SF  -  -
# 5410559   192.168.1.193    13  icmp     -      0.000005   56  ...  OTH  -  -
# 5410560   192.168.1.193     0  icmp     -      0.000005   56  ...  OTH  -  -
#
#         14          15    16     17    18      19  \
# 0        0  ShADadttfF   234  12994   285  418624
# 1        0  ShADadttfF   282  15702   282  412612
# 2        0  ShADadttfF   174   9600   201  291562
# 3        0           S     6    360     0       0
# 4        0  ShADadttfF   178   9840   196  284806
# ...     ..         ...   ...    ...   ...     ...
# 5410556  0           S     1     40     0       0
# 5410557  0      ShADad  1796  93758  1792  102154
# 5410558  0    ShADdfFr    10    558     8     430
# 5410559  0           -     2    112     0       0
# 5410560  0           -     2    112     0       0
#
#                                                 20
# 0                     -   Malicious   FileDownload
# 1                     -   Malicious   FileDownload
# 2                     -   Malicious   FileDownload
# 3                                   -   Benign   -
# 4                     -   Malicious   FileDownload
# ...                                            ...
# 5410556  -   Malicious   PartOfAHorizontalPortScan
# 5410557           -   Malicious   C&C-FileDownload
# 5410558                        -   Malicious   C&C
# 5410559                             -   Benign   -
# 5410560                             -   Benign   -
#
# [5410561 rows x 21 columns]

# %%
display(df)
# Out:
#                         0                   1                2      3   \
# 0        1551383431.142246   Cnkx4U1xJgOIPooe2    192.168.1.193  51358
# 1        1551383433.123797  C5t6Kp1UnQyH7JCC45    192.168.1.193  51360
# 2        1551383435.092740  CRdXqi4p3HG1obs6xl    192.168.1.193  51362
# 3        1551383437.567516  Co7Sfi3KfjPoJwW5Kf    192.168.1.193  51364
# 4        1551383444.739956  CKaKqD34bwvqLUcID9    192.168.1.193  51364
# ...                    ...                 ...              ...    ...
# 5410556  1551409817.668471  Ctc2If2AEpNehSWL2a    192.168.1.193  30535
# 5410557  1551383451.451091   CJm7HCnrDfDREbMm7    192.168.1.193  50178
# 5410558  1551409625.703405  C5uG6C4AFRl77HCJM9    192.168.1.193  52882
# 5410559  1551409780.796366  Cfdczo4DyzPUejtd0g  217.229.163.167      3
# 5410560  1551409777.981235  C3W3yA44vwV6ovDa2j        14.1.5.94     11
#
#                      4     5     6     7             8    9   ...   11 12 13  \
# 0        134.209.72.171    80   tcp  http      1.874424  149  ...   SF  -  -
# 1        134.209.72.171    80   tcp  http      1.871487  151  ...   SF  -  -
# 2        134.209.72.171    80   tcp  http      2.376374  148  ...   SF  -  -
# 3        134.209.72.171    80   tcp     -      3.092539    0  ...   S0  -  -
# 4        134.209.72.171    80   tcp  http      1.359780  148  ...   SF  -  -
# ...                 ...   ...   ...   ...           ...  ...  ...  ... .. ..
# 5410556   217.48.18.213  8081   tcp     -             -    -  ...   S0  -  -
# 5410557  134.209.72.171  4554   tcp     -  26347.422164   11  ...   S1  -  -
# 5410558  134.209.72.171  4554   tcp     -      0.304830   11  ...   SF  -  -
# 5410559   192.168.1.193    13  icmp     -      0.000005   56  ...  OTH  -  -
# 5410560   192.168.1.193     0  icmp     -      0.000005   56  ...  OTH  -  -
#
#         14          15    16     17    18      19  \
# 0        0  ShADadttfF   234  12994   285  418624
# 1        0  ShADadttfF   282  15702   282  412612
# 2        0  ShADadttfF   174   9600   201  291562
# 3        0           S     6    360     0       0
# 4        0  ShADadttfF   178   9840   196  284806
# ...     ..         ...   ...    ...   ...     ...
# 5410556  0           S     1     40     0       0
# 5410557  0      ShADad  1796  93758  1792  102154
# 5410558  0    ShADdfFr    10    558     8     430
# 5410559  0           -     2    112     0       0
# 5410560  0           -     2    112     0       0
#
#                                                 20
# 0                     -   Malicious   FileDownload
# 1                     -   Malicious   FileDownload
# 2                     -   Malicious   FileDownload
# 3                                   -   Benign   -
# 4                     -   Malicious   FileDownload
# ...                                            ...
# 5410556  -   Malicious   PartOfAHorizontalPortScan
# 5410557           -   Malicious   C&C-FileDownload
# 5410558                        -   Malicious   C&C
# 5410559                             -   Benign   -
# 5410560                             -   Benign   -
#
# [5410561 rows x 21 columns]

# %%
df[20].values[1:100]
# Out:
# array(['-   Malicious   FileDownload', '-   Malicious   FileDownload',
#        '-   Benign   -', '-   Malicious   FileDownload',
#        '-   Malicious   FileDownload',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan', '-   Malicious   C&C',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan',
#        '-   Malicious   PartOfAHorizontalPortScan'], dtype=object)

# %%
x
# Out:
# ['#fields',
#  'ts',
#  'uid',
#  'id.orig_h',
#  'id.orig_p',
#  'id.resp_h',
#  'id.resp_p',
#  'proto',
#  'service',
#  'duration',
#  'orig_bytes',
#  'resp_bytes',
#  'conn_state',
#  'local_orig',
#  'local_resp',
#  'missed_bytes',
#  'history',
#  'orig_pkts',
#  'orig_ip_bytes',
#  'resp_pkts',
#  'resp_ip_bytes',
#  'tunnel_parents   label   detailed-label\n']

# %%
x.pop(0)
# Out:
# '#fields'

# %%
x[20]='tunnel_parents   label   detailed-label'

# %%
x
# Out:
# ['ts',
#  'uid',
#  'id.orig_h',
#  'id.orig_p',
#  'id.resp_h',
#  'id.resp_p',
#  'proto',
#  'service',
#  'duration',
#  'orig_bytes',
#  'resp_bytes',
#  'conn_state',
#  'local_orig',
#  'local_resp',
#  'missed_bytes',
#  'history',
#  'orig_pkts',
#  'orig_ip_bytes',
#  'resp_pkts',
#  'resp_ip_bytes',
#  'tunnel_parents   label   detailed-label']

# %%
df.columns=x

# %%
df
# Out:
#                         ts                 uid        id.orig_h id.orig_p  \
# 0        1551383431.142246   Cnkx4U1xJgOIPooe2    192.168.1.193     51358
# 1        1551383433.123797  C5t6Kp1UnQyH7JCC45    192.168.1.193     51360
# 2        1551383435.092740  CRdXqi4p3HG1obs6xl    192.168.1.193     51362
# 3        1551383437.567516  Co7Sfi3KfjPoJwW5Kf    192.168.1.193     51364
# 4        1551383444.739956  CKaKqD34bwvqLUcID9    192.168.1.193     51364
# ...                    ...                 ...              ...       ...
# 5410556  1551409817.668471  Ctc2If2AEpNehSWL2a    192.168.1.193     30535
# 5410557  1551383451.451091   CJm7HCnrDfDREbMm7    192.168.1.193     50178
# 5410558  1551409625.703405  C5uG6C4AFRl77HCJM9    192.168.1.193     52882
# 5410559  1551409780.796366  Cfdczo4DyzPUejtd0g  217.229.163.167         3
# 5410560  1551409777.981235  C3W3yA44vwV6ovDa2j        14.1.5.94        11
#
#               id.resp_h id.resp_p proto service      duration orig_bytes  ...  \
# 0        134.209.72.171        80   tcp    http      1.874424        149  ...
# 1        134.209.72.171        80   tcp    http      1.871487        151  ...
# 2        134.209.72.171        80   tcp    http      2.376374        148  ...
# 3        134.209.72.171        80   tcp       -      3.092539          0  ...
# 4        134.209.72.171        80   tcp    http      1.359780        148  ...
# ...                 ...       ...   ...     ...           ...        ...  ...
# 5410556   217.48.18.213      8081   tcp       -             -          -  ...
# 5410557  134.209.72.171      4554   tcp       -  26347.422164         11  ...
# 5410558  134.209.72.171      4554   tcp       -      0.304830         11  ...
# 5410559   192.168.1.193        13  icmp       -      0.000005         56  ...
# 5410560   192.168.1.193         0  icmp       -      0.000005         56  ...
#
#         conn_state local_orig local_resp missed_bytes     history orig_pkts  \
# 0               SF          -          -            0  ShADadttfF       234
# 1               SF          -          -            0  ShADadttfF       282
# 2               SF          -          -            0  ShADadttfF       174
# 3               S0          -          -            0           S         6
# 4               SF          -          -            0  ShADadttfF       178
# ...            ...        ...        ...          ...         ...       ...
# 5410556         S0          -          -            0           S         1
# 5410557         S1          -          -            0      ShADad      1796
# 5410558         SF          -          -            0    ShADdfFr        10
# 5410559        OTH          -          -            0           -         2
# 5410560        OTH          -          -            0           -         2
#
#         orig_ip_bytes resp_pkts resp_ip_bytes  \
# 0               12994       285        418624
# 1               15702       282        412612
# 2                9600       201        291562
# 3                 360         0             0
# 4                9840       196        284806
# ...               ...       ...           ...
# 5410556            40         0             0
# 5410557         93758      1792        102154
# 5410558           558         8           430
# 5410559           112         0             0
# 5410560           112         0             0
#
#            tunnel_parents   label   detailed-label
# 0                     -   Malicious   FileDownload
# 1                     -   Malicious   FileDownload
# 2                     -   Malicious   FileDownload
# 3                                   -   Benign   -
# 4                     -   Malicious   FileDownload
# ...                                            ...
# 5410556  -   Malicious   PartOfAHorizontalPortScan
# 5410557           -   Malicious   C&C-FileDownload
# 5410558                        -   Malicious   C&C
# 5410559                             -   Benign   -
# 5410560                             -   Benign   -
#
# [5410561 rows x 21 columns]

# %%
df.to_csv("49.csv")
