# %%
import numpy as np
import pandas as pd
# Assign the filename
fpath = r"3.labeled"
# Import file using np.recfromcsv: d
narray = np.recfromcsv(fpath, encoding=None)

# Print out first n records of d 
print(narray)
# string to search in file
word = 'fields'
with open(fpath, 'r') as fp:
    # read all lines in a list
    lines = fp.readlines()
    for line in lines:
        # check if string present on a current line
        if line.find(word) != -1:
            print(word, 'string exists in file')
            print('Line Number:', lines.index(line))
            print('Line:', line)
            linefields = line
x = linefields.split("\t")
df = pd.concat([pd.Series(l.astype(str).split('\t')) for l in narray], axis=1).T
print(df)
# Out:
# [('1526756261.866500\tC9YvmJ3zxtuqxWxLW5\t192.168.2.5\t38792\t200.168.87.203\t59353\ttcp\t-\t2.998333\t0\t0\tS0\t-\t-\t0\tS\t3\t180\t0\t0\t(empty)   Malicious   PartOfAHorizontalPortScan',)
#  ('1526756268.874876\tCGsZqZ3UiQexLzPRVb\t192.168.2.5\t38792\t200.168.87.203\t59353\ttcp\t-\t-\t-\t-\tS0\t-\t-\t0\tS\t1\t60\t0\t0\t(empty)   Malicious   PartOfAHorizontalPortScan',)
#  ('1526756272.877722\tC0LkBW2VEa292Nvet8\t192.168.2.5\t38793\t200.168.87.203\t59353\ttcp\t-\t2.997182\t0\t0\tS0\t-\t-\t0\tS\t3\t180\t0\t0\t(empty)   Malicious   PartOfAHorizontalPortScan',)
#  ...
#  ('1526886282.960912\tCc5Jwn4krKLqvFHdG1\t192.168.2.5\t36647\t200.168.87.203\t59353\ttcp\t-\t-\t-\t-\tS0\t-\t-\t0\tS\t1\t60\t0\t0\t(empty)   Malicious   PartOfAHorizontalPortScan',)
#  ('1526886286.965803\tCk8fNL3RpnSPu9Kn9e\t192.168.2.5\t36648\t200.168.87.203\t59353\ttcp\t-\t0.995112\t0\t0\tS0\t-\t-\t0\tS\t2\t120\t0\t0\t(empty)   Malicious   PartOfAHorizontalPortScan',)
#  ('1526792995.887377\tCY3eGl3hKYsrYxwFv6\t192.168.2.5\t41501\t54.39.23.28\t2407\ttcp\tirc\t93280.030966\t6303\t9069\tS1\t-\t-\t0\tShADad\t3031\t164117\t5975\t289732\t(empty)   Malicious   C&C',)]
# fields string exists in file
# Line Number: 6
# Line: #fields	ts	uid	id.orig_h	id.orig_p	id.resp_h	id.resp_p	proto	service	duration	orig_bytes	resp_bytes	conn_state	local_orig	local_resp	missed_bytes	history	orig_pkts	orig_ip_bytes	resp_pkts	resp_ip_bytes	tunnel_parents   label   detailed-label
#
#                        0                   1            2      3   \
# 0       1526756261.866500  C9YvmJ3zxtuqxWxLW5  192.168.2.5  38792
# 1       1526756268.874876  CGsZqZ3UiQexLzPRVb  192.168.2.5  38792
# 2       1526756272.877722  C0LkBW2VEa292Nvet8  192.168.2.5  38793
# 3       1526756279.884959  CMDLrn2cVhrqvW8gKa  192.168.2.5  38793
# 4       1526756283.888751  C2UM8f4knuL5Vnvp3h  192.168.2.5  38794
# ...                   ...                 ...          ...    ...
# 156098  1526886271.950896  CzeVGM1n60FIryJyBi  192.168.2.5  36646
# 156099  1526886275.954933   Cq9Oi6YyGNTJlf356  192.168.2.5  36647
# 156100  1526886282.960912  Cc5Jwn4krKLqvFHdG1  192.168.2.5  36647
# 156101  1526886286.965803  Ck8fNL3RpnSPu9Kn9e  192.168.2.5  36648
# 156102  1526792995.887377  CY3eGl3hKYsrYxwFv6  192.168.2.5  41501
#
#                     4      5    6    7             8     9   ...  11 12 13 14  \
# 0       200.168.87.203  59353  tcp    -      2.998333     0  ...  S0  -  -  0
# 1       200.168.87.203  59353  tcp    -             -     -  ...  S0  -  -  0
# 2       200.168.87.203  59353  tcp    -      2.997182     0  ...  S0  -  -  0
# 3       200.168.87.203  59353  tcp    -             -     -  ...  S0  -  -  0
# 4       200.168.87.203  59353  tcp    -      2.996286     0  ...  S0  -  -  0
# ...                ...    ...  ...  ...           ...   ...  ...  .. .. .. ..
# 156098  200.168.87.203  59353  tcp    -             -     -  ...  S0  -  -  0
# 156099  200.168.87.203  59353  tcp    -      2.996060     0  ...  S0  -  -  0
# 156100  200.168.87.203  59353  tcp    -             -     -  ...  S0  -  -  0
# 156101  200.168.87.203  59353  tcp    -      0.995112     0  ...  S0  -  -  0
# 156102     54.39.23.28   2407  tcp  irc  93280.030966  6303  ...  S1  -  -  0
#
#             15    16      17    18      19  \
# 0            S     3     180     0       0
# 1            S     1      60     0       0
# 2            S     3     180     0       0
# 3            S     1      60     0       0
# 4            S     3     180     0       0
# ...        ...   ...     ...   ...     ...
# 156098       S     1      60     0       0
# 156099       S     3     180     0       0
# 156100       S     1      60     0       0
# 156101       S     2     120     0       0
# 156102  ShADad  3031  164117  5975  289732
#
#                                                      20
# 0       (empty)   Malicious   PartOfAHorizontalPortScan
# 1       (empty)   Malicious   PartOfAHorizontalPortScan
# 2       (empty)   Malicious   PartOfAHorizontalPortScan
# 3       (empty)   Malicious   PartOfAHorizontalPortScan
# 4       (empty)   Malicious   PartOfAHorizontalPortScan
# ...                                                 ...
# 156098  (empty)   Malicious   PartOfAHorizontalPortScan
# 156099  (empty)   Malicious   PartOfAHorizontalPortScan
# 156100  (empty)   Malicious   PartOfAHorizontalPortScan
# 156101  (empty)   Malicious   PartOfAHorizontalPortScan
# 156102                        (empty)   Malicious   C&C
#
# [156103 rows x 21 columns]

# %%
display(df)
# Out:
#                        0                   1            2      3   \
# 0       1526756261.866500  C9YvmJ3zxtuqxWxLW5  192.168.2.5  38792
# 1       1526756268.874876  CGsZqZ3UiQexLzPRVb  192.168.2.5  38792
# 2       1526756272.877722  C0LkBW2VEa292Nvet8  192.168.2.5  38793
# 3       1526756279.884959  CMDLrn2cVhrqvW8gKa  192.168.2.5  38793
# 4       1526756283.888751  C2UM8f4knuL5Vnvp3h  192.168.2.5  38794
# ...                   ...                 ...          ...    ...
# 156098  1526886271.950896  CzeVGM1n60FIryJyBi  192.168.2.5  36646
# 156099  1526886275.954933   Cq9Oi6YyGNTJlf356  192.168.2.5  36647
# 156100  1526886282.960912  Cc5Jwn4krKLqvFHdG1  192.168.2.5  36647
# 156101  1526886286.965803  Ck8fNL3RpnSPu9Kn9e  192.168.2.5  36648
# 156102  1526792995.887377  CY3eGl3hKYsrYxwFv6  192.168.2.5  41501
#
#                     4      5    6    7             8     9   ...  11 12 13 14  \
# 0       200.168.87.203  59353  tcp    -      2.998333     0  ...  S0  -  -  0
# 1       200.168.87.203  59353  tcp    -             -     -  ...  S0  -  -  0
# 2       200.168.87.203  59353  tcp    -      2.997182     0  ...  S0  -  -  0
# 3       200.168.87.203  59353  tcp    -             -     -  ...  S0  -  -  0
# 4       200.168.87.203  59353  tcp    -      2.996286     0  ...  S0  -  -  0
# ...                ...    ...  ...  ...           ...   ...  ...  .. .. .. ..
# 156098  200.168.87.203  59353  tcp    -             -     -  ...  S0  -  -  0
# 156099  200.168.87.203  59353  tcp    -      2.996060     0  ...  S0  -  -  0
# 156100  200.168.87.203  59353  tcp    -             -     -  ...  S0  -  -  0
# 156101  200.168.87.203  59353  tcp    -      0.995112     0  ...  S0  -  -  0
# 156102     54.39.23.28   2407  tcp  irc  93280.030966  6303  ...  S1  -  -  0
#
#             15    16      17    18      19  \
# 0            S     3     180     0       0
# 1            S     1      60     0       0
# 2            S     3     180     0       0
# 3            S     1      60     0       0
# 4            S     3     180     0       0
# ...        ...   ...     ...   ...     ...
# 156098       S     1      60     0       0
# 156099       S     3     180     0       0
# 156100       S     1      60     0       0
# 156101       S     2     120     0       0
# 156102  ShADad  3031  164117  5975  289732
#
#                                                      20
# 0       (empty)   Malicious   PartOfAHorizontalPortScan
# 1       (empty)   Malicious   PartOfAHorizontalPortScan
# 2       (empty)   Malicious   PartOfAHorizontalPortScan
# 3       (empty)   Malicious   PartOfAHorizontalPortScan
# 4       (empty)   Malicious   PartOfAHorizontalPortScan
# ...                                                 ...
# 156098  (empty)   Malicious   PartOfAHorizontalPortScan
# 156099  (empty)   Malicious   PartOfAHorizontalPortScan
# 156100  (empty)   Malicious   PartOfAHorizontalPortScan
# 156101  (empty)   Malicious   PartOfAHorizontalPortScan
# 156102                        (empty)   Malicious   C&C
#
# [156103 rows x 21 columns]

# %%
df[20].values[1:100]
# Out:
# array(['(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Benign   -',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Benign   -',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Malicious   C&C',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Benign   -',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Benign   -',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Benign   -',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Benign   -',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Benign   -',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Malicious   PartOfAHorizontalPortScan',
#        '(empty)   Benign   -',
#        '(empty)   Malicious   PartOfAHorizontalPortScan'], dtype=object)

# %%
x
# Out:
# ['#fields',
#  'ts',
#  'uid',
#  'id.orig_h',
#  'id.orig_p',
#  'id.resp_h',
#  'id.resp_p',
#  'proto',
#  'service',
#  'duration',
#  'orig_bytes',
#  'resp_bytes',
#  'conn_state',
#  'local_orig',
#  'local_resp',
#  'missed_bytes',
#  'history',
#  'orig_pkts',
#  'orig_ip_bytes',
#  'resp_pkts',
#  'resp_ip_bytes',
#  'tunnel_parents   label   detailed-label\n']

# %%
x.pop(0)
# Out:
# '#fields'

# %%
x[20]='tunnel_parents   label   detailed-label'

# %%
x
# Out:
# ['ts',
#  'uid',
#  'id.orig_h',
#  'id.orig_p',
#  'id.resp_h',
#  'id.resp_p',
#  'proto',
#  'service',
#  'duration',
#  'orig_bytes',
#  'resp_bytes',
#  'conn_state',
#  'local_orig',
#  'local_resp',
#  'missed_bytes',
#  'history',
#  'orig_pkts',
#  'orig_ip_bytes',
#  'resp_pkts',
#  'resp_ip_bytes',
#  'tunnel_parents   label   detailed-label']

# %%
df.columns=x

# %%
df
# Out:
#                        ts                 uid    id.orig_h id.orig_p  \
# 0       1526756261.866500  C9YvmJ3zxtuqxWxLW5  192.168.2.5     38792
# 1       1526756268.874876  CGsZqZ3UiQexLzPRVb  192.168.2.5     38792
# 2       1526756272.877722  C0LkBW2VEa292Nvet8  192.168.2.5     38793
# 3       1526756279.884959  CMDLrn2cVhrqvW8gKa  192.168.2.5     38793
# 4       1526756283.888751  C2UM8f4knuL5Vnvp3h  192.168.2.5     38794
# ...                   ...                 ...          ...       ...
# 156098  1526886271.950896  CzeVGM1n60FIryJyBi  192.168.2.5     36646
# 156099  1526886275.954933   Cq9Oi6YyGNTJlf356  192.168.2.5     36647
# 156100  1526886282.960912  Cc5Jwn4krKLqvFHdG1  192.168.2.5     36647
# 156101  1526886286.965803  Ck8fNL3RpnSPu9Kn9e  192.168.2.5     36648
# 156102  1526792995.887377  CY3eGl3hKYsrYxwFv6  192.168.2.5     41501
#
#              id.resp_h id.resp_p proto service      duration orig_bytes  ...  \
# 0       200.168.87.203     59353   tcp       -      2.998333          0  ...
# 1       200.168.87.203     59353   tcp       -             -          -  ...
# 2       200.168.87.203     59353   tcp       -      2.997182          0  ...
# 3       200.168.87.203     59353   tcp       -             -          -  ...
# 4       200.168.87.203     59353   tcp       -      2.996286          0  ...
# ...                ...       ...   ...     ...           ...        ...  ...
# 156098  200.168.87.203     59353   tcp       -             -          -  ...
# 156099  200.168.87.203     59353   tcp       -      2.996060          0  ...
# 156100  200.168.87.203     59353   tcp       -             -          -  ...
# 156101  200.168.87.203     59353   tcp       -      0.995112          0  ...
# 156102     54.39.23.28      2407   tcp     irc  93280.030966       6303  ...
#
#        conn_state local_orig local_resp missed_bytes history orig_pkts  \
# 0              S0          -          -            0       S         3
# 1              S0          -          -            0       S         1
# 2              S0          -          -            0       S         3
# 3              S0          -          -            0       S         1
# 4              S0          -          -            0       S         3
# ...           ...        ...        ...          ...     ...       ...
# 156098         S0          -          -            0       S         1
# 156099         S0          -          -            0       S         3
# 156100         S0          -          -            0       S         1
# 156101         S0          -          -            0       S         2
# 156102         S1          -          -            0  ShADad      3031
#
#        orig_ip_bytes resp_pkts resp_ip_bytes  \
# 0                180         0             0
# 1                 60         0             0
# 2                180         0             0
# 3                 60         0             0
# 4                180         0             0
# ...              ...       ...           ...
# 156098            60         0             0
# 156099           180         0             0
# 156100            60         0             0
# 156101           120         0             0
# 156102        164117      5975        289732
#
#                 tunnel_parents   label   detailed-label
# 0       (empty)   Malicious   PartOfAHorizontalPortScan
# 1       (empty)   Malicious   PartOfAHorizontalPortScan
# 2       (empty)   Malicious   PartOfAHorizontalPortScan
# 3       (empty)   Malicious   PartOfAHorizontalPortScan
# 4       (empty)   Malicious   PartOfAHorizontalPortScan
# ...                                                 ...
# 156098  (empty)   Malicious   PartOfAHorizontalPortScan
# 156099  (empty)   Malicious   PartOfAHorizontalPortScan
# 156100  (empty)   Malicious   PartOfAHorizontalPortScan
# 156101  (empty)   Malicious   PartOfAHorizontalPortScan
# 156102                        (empty)   Malicious   C&C
#
# [156103 rows x 21 columns]

# %%
df.to_csv("3.csv")
