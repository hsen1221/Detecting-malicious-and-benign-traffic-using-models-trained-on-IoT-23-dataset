# %%
import numpy as np
import pandas as pd
# Assign the filename
fpath = r"8conn.log.labeled"
# Import file using np.recfromcsv: d
narray = np.recfromcsv(fpath, encoding=None)

# Print out first n records of d 
print(narray)
# string to search in file
word = 'fields'
with open(fpath, 'r') as fp:
    # read all lines in a list
    lines = fp.readlines()
    for line in lines:
        # check if string present on a current line
        if line.find(word) != -1:
            print(word, 'string exists in file')
            print('Line Number:', lines.index(line))
            print('Line:', line)
            linefields = line
x = linefields.split("\t")
df = pd.concat([pd.Series(l.astype(str).split('\t')) for l in narray], axis=1).T
print(df)
# Out:
# [('1533042911.474174\tC5JLGOoxIw2dBZt47\t192.168.100.113\t123\t81.2.254.224\t123\tudp\t-\t0.005490\t48\t48\tSF\t-\t-\t0\tDd\t1\t76\t1\t76\t(empty)   Benign   -',)
#  ('1533042921.474234\tCf3cHf4jZr9nvD808i\t192.168.100.113\t123\t147.231.100.5\t123\tudp\t-\t0.001741\t48\t48\tSF\t-\t-\t0\tDd\t1\t76\t1\t76\t(empty)   Benign   -',)
#  ('1533042944.474388\tCJgmSt3bSY6XwE9fzc\t192.168.100.113\t123\t31.31.74.35\t123\tudp\t-\t0.004495\t48\t48\tSF\t-\t-\t0\tDd\t1\t76\t1\t76\t(empty)   Benign   -',)
#  ...
#  ('1533129306.734905\tCkMeQi2atLqx0NfAR\t192.168.100.113\t38252\t128.185.250.50\t50\ttcp\t-\t-\t-\t-\tS0\t-\t-\t0\tS\t1\t60\t0\t0\t(empty)   Malicious   C&C',)
#  ('1533129249.474988\tCypjCo4WicqE74GkUl\t192.168.100.113\t123\t147.231.100.5\t123\tudp\t-\t0.001988\t48\t48\tSF\t-\t-\t0\tDd\t1\t76\t1\t76\t(empty)   Benign   -',)
#  ('1533129253.475215\tCC4Tss16O1KtMckgZj\t192.168.100.113\t123\t147.251.48.140\t123\tudp\t-\t0.005233\t48\t48\tSF\t-\t-\t0\tDd\t1\t76\t1\t76\t(empty)   Benign   -',)]
# fields string exists in file
# Line Number: 6
# Line: #fields	ts	uid	id.orig_h	id.orig_p	id.resp_h	id.resp_p	proto	service	duration	orig_bytes	resp_bytes	conn_state	local_orig	local_resp	missed_bytes	history	orig_pkts	orig_ip_bytes	resp_pkts	resp_ip_bytes	tunnel_parents   label   detailed-label
#
#                       0                   1                2      3   \
# 0      1533042911.474174   C5JLGOoxIw2dBZt47  192.168.100.113    123
# 1      1533042921.474234  Cf3cHf4jZr9nvD808i  192.168.100.113    123
# 2      1533042944.474388  CJgmSt3bSY6XwE9fzc  192.168.100.113    123
# 3      1533042976.474182  Cav32m4csR3OZYhShj  192.168.100.113    123
# 4      1533042988.474356  ClwPfA40tU9UT4nksg  192.168.100.113    123
# ...                  ...                 ...              ...    ...
# 10398  1533129296.895007  CnFPqm2V3khhpDHVph  192.168.100.113  47432
# 10399  1533129299.565752  C76idj4jtLwpz9S3L7  192.168.100.113  38252
# 10400  1533129306.734905   CkMeQi2atLqx0NfAR  192.168.100.113  38252
# 10401  1533129249.474988  CypjCo4WicqE74GkUl  192.168.100.113    123
# 10402  1533129253.475215  CC4Tss16O1KtMckgZj  192.168.100.113    123
#
#                     4    5    6  7         8   9   ...  11 12 13 14  15 16  \
# 0         81.2.254.224  123  udp  -  0.005490  48  ...  SF  -  -  0  Dd  1
# 1        147.231.100.5  123  udp  -  0.001741  48  ...  SF  -  -  0  Dd  1
# 2          31.31.74.35  123  udp  -  0.004495  48  ...  SF  -  -  0  Dd  1
# 3       147.251.48.140  123  udp  -  0.006988  48  ...  SF  -  -  0  Dd  1
# 4        147.231.100.5  123  udp  -  0.001487  48  ...  SF  -  -  0  Dd  1
# ...                ...  ...  ... ..       ...  ..  ...  .. .. .. ..  .. ..
# 10398  178.128.185.250   50  tcp  -         -   -  ...  S0  -  -  0   S  1
# 10399   128.185.250.50   50  tcp  -  3.089221   0  ...  S0  -  -  0   S  3
# 10400   128.185.250.50   50  tcp  -         -   -  ...  S0  -  -  0   S  1
# 10401    147.231.100.5  123  udp  -  0.001988  48  ...  SF  -  -  0  Dd  1
# 10402   147.251.48.140  123  udp  -  0.005233  48  ...  SF  -  -  0  Dd  1
#
#         17 18  19                         20
# 0       76  1  76       (empty)   Benign   -
# 1       76  1  76       (empty)   Benign   -
# 2       76  1  76       (empty)   Benign   -
# 3       76  1  76       (empty)   Benign   -
# 4       76  1  76       (empty)   Benign   -
# ...    ... ..  ..                        ...
# 10398   60  0   0  (empty)   Malicious   C&C
# 10399  180  0   0  (empty)   Malicious   C&C
# 10400   60  0   0  (empty)   Malicious   C&C
# 10401   76  1  76       (empty)   Benign   -
# 10402   76  1  76       (empty)   Benign   -
#
# [10403 rows x 21 columns]

# %%
display(df)
# Out:
#                       0                   1                2      3   \
# 0      1533042911.474174   C5JLGOoxIw2dBZt47  192.168.100.113    123
# 1      1533042921.474234  Cf3cHf4jZr9nvD808i  192.168.100.113    123
# 2      1533042944.474388  CJgmSt3bSY6XwE9fzc  192.168.100.113    123
# 3      1533042976.474182  Cav32m4csR3OZYhShj  192.168.100.113    123
# 4      1533042988.474356  ClwPfA40tU9UT4nksg  192.168.100.113    123
# ...                  ...                 ...              ...    ...
# 10398  1533129296.895007  CnFPqm2V3khhpDHVph  192.168.100.113  47432
# 10399  1533129299.565752  C76idj4jtLwpz9S3L7  192.168.100.113  38252
# 10400  1533129306.734905   CkMeQi2atLqx0NfAR  192.168.100.113  38252
# 10401  1533129249.474988  CypjCo4WicqE74GkUl  192.168.100.113    123
# 10402  1533129253.475215  CC4Tss16O1KtMckgZj  192.168.100.113    123
#
#                     4    5    6  7         8   9   ...  11 12 13 14  15 16  \
# 0         81.2.254.224  123  udp  -  0.005490  48  ...  SF  -  -  0  Dd  1
# 1        147.231.100.5  123  udp  -  0.001741  48  ...  SF  -  -  0  Dd  1
# 2          31.31.74.35  123  udp  -  0.004495  48  ...  SF  -  -  0  Dd  1
# 3       147.251.48.140  123  udp  -  0.006988  48  ...  SF  -  -  0  Dd  1
# 4        147.231.100.5  123  udp  -  0.001487  48  ...  SF  -  -  0  Dd  1
# ...                ...  ...  ... ..       ...  ..  ...  .. .. .. ..  .. ..
# 10398  178.128.185.250   50  tcp  -         -   -  ...  S0  -  -  0   S  1
# 10399   128.185.250.50   50  tcp  -  3.089221   0  ...  S0  -  -  0   S  3
# 10400   128.185.250.50   50  tcp  -         -   -  ...  S0  -  -  0   S  1
# 10401    147.231.100.5  123  udp  -  0.001988  48  ...  SF  -  -  0  Dd  1
# 10402   147.251.48.140  123  udp  -  0.005233  48  ...  SF  -  -  0  Dd  1
#
#         17 18  19                         20
# 0       76  1  76       (empty)   Benign   -
# 1       76  1  76       (empty)   Benign   -
# 2       76  1  76       (empty)   Benign   -
# 3       76  1  76       (empty)   Benign   -
# 4       76  1  76       (empty)   Benign   -
# ...    ... ..  ..                        ...
# 10398   60  0   0  (empty)   Malicious   C&C
# 10399  180  0   0  (empty)   Malicious   C&C
# 10400   60  0   0  (empty)   Malicious   C&C
# 10401   76  1  76       (empty)   Benign   -
# 10402   76  1  76       (empty)   Benign   -
#
# [10403 rows x 21 columns]

# %%
df[20].values[1:100]
# Out:
# array(['(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -', '(empty)   Benign   -',
#        '(empty)   Benign   -'], dtype=object)

# %%
x
# Out:
# ['#fields',
#  'ts',
#  'uid',
#  'id.orig_h',
#  'id.orig_p',
#  'id.resp_h',
#  'id.resp_p',
#  'proto',
#  'service',
#  'duration',
#  'orig_bytes',
#  'resp_bytes',
#  'conn_state',
#  'local_orig',
#  'local_resp',
#  'missed_bytes',
#  'history',
#  'orig_pkts',
#  'orig_ip_bytes',
#  'resp_pkts',
#  'resp_ip_bytes',
#  'tunnel_parents   label   detailed-label\n']

# %%
x.pop(0)
# Out:
# '#fields'

# %%
x[20]='tunnel_parents   label   detailed-label'

# %%
x
# Out:
# ['ts',
#  'uid',
#  'id.orig_h',
#  'id.orig_p',
#  'id.resp_h',
#  'id.resp_p',
#  'proto',
#  'service',
#  'duration',
#  'orig_bytes',
#  'resp_bytes',
#  'conn_state',
#  'local_orig',
#  'local_resp',
#  'missed_bytes',
#  'history',
#  'orig_pkts',
#  'orig_ip_bytes',
#  'resp_pkts',
#  'resp_ip_bytes',
#  'tunnel_parents   label   detailed-label']

# %%
df.columns=x

# %%
df
# Out:
#                       ts                 uid        id.orig_h id.orig_p  \
# 0      1533042911.474174   C5JLGOoxIw2dBZt47  192.168.100.113       123
# 1      1533042921.474234  Cf3cHf4jZr9nvD808i  192.168.100.113       123
# 2      1533042944.474388  CJgmSt3bSY6XwE9fzc  192.168.100.113       123
# 3      1533042976.474182  Cav32m4csR3OZYhShj  192.168.100.113       123
# 4      1533042988.474356  ClwPfA40tU9UT4nksg  192.168.100.113       123
# ...                  ...                 ...              ...       ...
# 10398  1533129296.895007  CnFPqm2V3khhpDHVph  192.168.100.113     47432
# 10399  1533129299.565752  C76idj4jtLwpz9S3L7  192.168.100.113     38252
# 10400  1533129306.734905   CkMeQi2atLqx0NfAR  192.168.100.113     38252
# 10401  1533129249.474988  CypjCo4WicqE74GkUl  192.168.100.113       123
# 10402  1533129253.475215  CC4Tss16O1KtMckgZj  192.168.100.113       123
#
#              id.resp_h id.resp_p proto service  duration orig_bytes  ...  \
# 0         81.2.254.224       123   udp       -  0.005490         48  ...
# 1        147.231.100.5       123   udp       -  0.001741         48  ...
# 2          31.31.74.35       123   udp       -  0.004495         48  ...
# 3       147.251.48.140       123   udp       -  0.006988         48  ...
# 4        147.231.100.5       123   udp       -  0.001487         48  ...
# ...                ...       ...   ...     ...       ...        ...  ...
# 10398  178.128.185.250        50   tcp       -         -          -  ...
# 10399   128.185.250.50        50   tcp       -  3.089221          0  ...
# 10400   128.185.250.50        50   tcp       -         -          -  ...
# 10401    147.231.100.5       123   udp       -  0.001988         48  ...
# 10402   147.251.48.140       123   udp       -  0.005233         48  ...
#
#       conn_state local_orig local_resp missed_bytes history orig_pkts  \
# 0             SF          -          -            0      Dd         1
# 1             SF          -          -            0      Dd         1
# 2             SF          -          -            0      Dd         1
# 3             SF          -          -            0      Dd         1
# 4             SF          -          -            0      Dd         1
# ...          ...        ...        ...          ...     ...       ...
# 10398         S0          -          -            0       S         1
# 10399         S0          -          -            0       S         3
# 10400         S0          -          -            0       S         1
# 10401         SF          -          -            0      Dd         1
# 10402         SF          -          -            0      Dd         1
#
#       orig_ip_bytes resp_pkts resp_ip_bytes  \
# 0                76         1            76
# 1                76         1            76
# 2                76         1            76
# 3                76         1            76
# 4                76         1            76
# ...             ...       ...           ...
# 10398            60         0             0
# 10399           180         0             0
# 10400            60         0             0
# 10401            76         1            76
# 10402            76         1            76
#
#       tunnel_parents   label   detailed-label
# 0                        (empty)   Benign   -
# 1                        (empty)   Benign   -
# 2                        (empty)   Benign   -
# 3                        (empty)   Benign   -
# 4                        (empty)   Benign   -
# ...                                       ...
# 10398               (empty)   Malicious   C&C
# 10399               (empty)   Malicious   C&C
# 10400               (empty)   Malicious   C&C
# 10401                    (empty)   Benign   -
# 10402                    (empty)   Benign   -
#
# [10403 rows x 21 columns]

# %%
df.to_csv("8.csv")
